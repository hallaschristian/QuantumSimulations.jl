# %%
using Revise

# %%
using Distributed
procs_to_use = 1

if nprocs() <= procs_to_use
    addprocs(procs_to_use-nprocs())
end

@everywhere using
    QuantumStates,
    OpticalBlochEquations,
    DifferentialEquations,
    UnitsToValue,
    LinearAlgebra,
    Printf,
    Plots,
    Random,
    StatsBase,
    Distributions,
    StructArrays,
    StaticArrays,
    StructArrays,
    LoopVectorization,
    Parameters,
    MutableNamedTuples

@everywhere @consts begin
    λ = 687e-9
    Γ = 2π * 6.4e6
    m = @with_unit 105 "u"
    k = 2π / λ
    _μB = (μB / h) * 1e-4
    kB = 1.380649e-23
end
;
# Out:
# [ Info: Precompiling OpticalBlochEquations [691d0331-80d3-41b1-b293-7891a6f4a14f]
# WARNING: Method definition operator_matrix_expectation(Any, Any) in module OpticalBlochEquations at C:\Google Drive\github\OpticalBlochEquations\src\obe.jl:605 overwritten at C:\Google Drive\github\OpticalBlochEquations\src\stochastic_schrodinger.jl:1624.
#   ** incremental compilation may be fatally broken for this module **

# %%
@everywhere begin
    Isat = π*c*h*Γ/(3*λ^3) # saturation intensity in mW/cm^2
    P = 2.5 * 13.6e-3 # power in mW, converting from voltage (1 V = 13.6 mW)
    I = 2P / (π * (5e-3)^2)
    s = I/Isat
end

# %%
const RF_frequency = 2π * 1.4e6 / Γ
;

# %%
@everywhere sim_params = MutableNamedTuple(

    # Notes:
    # B-field gradient should be given in amplitude, not RMS
    
    pol_imbalance = 0.0,
    s_imbalance = (0.0, 0.0, 0.0),
    retro_loss = 0.0,
    off_center = (0,0,0,0,0,0) .* 1e-3,
    pointing_error = (0,0,0,0,0,0),

    ### 2-FREQUENCY RF MOT ###
    RF_frequency = 2π * 1.4e6 / Γ,
    B_gradient = +5.0 * √2,
    B_offset = (0e-3, 0e-3, 0e-3),
    s1 = s/20,
    s2 = s/20,
    s3 = s/8,
    s4 = s/8,
    Δ1 = -2Γ,
    Δ2 = -2Γ,
    Δ3 = -4Γ,
    Δ4 = -4Γ,
    pol1_x = [1,0,0],
    pol2_x = [0,0,1],
    pol3_x = [1,0,0],
    pol4_x = [0,0,1],

    # slowing lasers parameters
    s5 = 0 * 3s,
    s6 = 0 * 3s,
    Δ5 = -6Γ,
    Δ6 = -6Γ,
    pol5_x = [1,0,0],
    pol6_x = [0,0,1]
)
;

# %% [markdown]
# ### Calculate transition dipole moments

# %%
@everywhere begin
    include("define_SrOH_states.jl")
    X_states, A_states = define_CaOH_states()
    states = [X_states; A_states[1:4]]
    d = tdms_between_states(states, states)
end
;

# %% [markdown]
# ### Define lasers

# %%
@everywhere begin
    include("define_lasers.jl")
    lasers = define_lasers(
        states,
        sim_params.RF_frequency,
        sim_params.s1,
        sim_params.s2,
        sim_params.s3,
        sim_params.s4,
        sim_params.Δ1,
        sim_params.Δ2,
        sim_params.Δ3,
        sim_params.Δ4,
        sim_params.pol1_x,
        sim_params.pol2_x,
        sim_params.pol3_x,
        sim_params.pol4_x,
        sim_params.pol_imbalance,
        sim_params.s_imbalance,
        sim_params.retro_loss,
        sim_params.off_center,
        sim_params.pointing_error,
        sim_params.s5,
        sim_params.s6,
        sim_params.Δ5,
        sim_params.Δ6,
        sim_params.pol5_x,
        sim_params.pol6_x
    )
end
;

# %%
@everywhere begin
    
    # J=1/2 components
    ϵJ12 = σ⁻
    s1 = s/32
    s2 = s/16
    s3 = s/2
    s4 = 0s/4
    ω1 = 2π * (energy(states[end]) - energy(states[1])) - 1Γ
    ω2 = 2π * (energy(states[end]) - energy(states[1])) - 2Γ
    ω3 = 2π * (energy(states[end]) - energy(states[1])) - 3Γ
    ω4 = 2π * (energy(states[end]) - energy(states[1])) - 4Γ
    
    # J=3/2 components
    ϵJ32 = σ⁺
    s5 = s/32
    s6 = s/16
    s7 = s/2
    s8 = 0s/4
    ω5 = 2π * (energy(states[end]) - energy(states[5])) - 1Γ
    ω6 = 2π * (energy(states[end]) - energy(states[5])) - 2Γ
    ω7 = 2π * (energy(states[end]) - energy(states[5])) - 3Γ
    ω8 = 2π * (energy(states[end]) - energy(states[5])) - 4Γ
    
    lasers_tuple1 = [
        (ω1, ϵJ12, s1),
        (ω2, ϵJ12, s2),
        (ω3, ϵJ12, s3),
        (ω4, ϵJ12, s4),
        (ω5, ϵJ32, s5),
        (ω6, ϵJ32, s6),
        (ω7, ϵJ32, s7),
        (ω8, ϵJ32, s8)
    ]

    include("define_lasers_updated.jl")
    lasers1 = define_lasers(
        sim_params.RF_frequency,
        lasers_tuple1
    )
    
    ## Define a "slowing" beam going against x + y
    # J=1/2 components
    s1 = s/4
    s2 = s/4
    s3 = s/4
    s4 = s/4
    ω1 = 2π * (energy(states[end]) - energy(states[1])) - 5Γ
    ω2 = 2π * (energy(states[end]) - energy(states[1])) - 7Γ
    ω3 = 2π * (energy(states[end]) - energy(states[1])) - 9Γ
    ω4 = 2π * (energy(states[end]) - energy(states[1])) - 11Γ

    # J=3/2 components
    s5 = s/4
    s6 = s/4
    s7 = s/4
    s8 = s/4
    ω5 = 2π * (energy(states[end]) - energy(states[5])) - 5Γ
    ω6 = 2π * (energy(states[end]) - energy(states[5])) - 7Γ
    ω7 = 2π * (energy(states[end]) - energy(states[5])) - 9Γ
    ω8 = 2π * (energy(states[end]) - energy(states[5])) - 11Γ
    
    lasers_tuple2 = [
        (ω1, ϵJ32, s1),
        (ω2, ϵJ32, s2),
        (ω3, ϵJ32, s3),
        (ω4, ϵJ32, s4),
        (ω5, ϵJ12, s5),
        (ω6, ϵJ12, s6),
        (ω7, ϵJ12, s7),
        (ω8, ϵJ12, s8)
    ]
    
    include("define_lasers_updated3.jl")
    lasers2 = define_lasers(
        sim_params.RF_frequency,
        lasers_tuple2
    )
    
    # lasers = lasers1
    lasers = [lasers1; lasers2]
    lasers = convert(Vector{Field{Float64, typeof(lasers[1].ϵ), typeof(lasers[1].s_func)}}, lasers)
    
end

# %%
@everywhere begin
  
    ωJ12 = 2π * (energy(states[end]) - energy(states[1]))
    ωJ32 = 2π * (energy(states[end]) - energy(states[5]))
#     # J=1/2 components  
#     ϵJ12 = σ⁻
#     s1 = s/8
#     s2 = s/8
#     s3 = s/8
#     s4 = s/8
#     ω1 = 2π * ωJ12 - 7Γ
#     ω2 = 2π * ωJ12 - 8Γ
#     ω3 = 2π * ωJ12 - 9Γ
#     ω4 = 2π * ωJ12 - 10Γ
    
#     # J=3/2 components
#     ϵJ32 = σ⁺
#     s5 = s/8
#     s6 = s/8
#     s7 = s/8
#     s8 = s/8
#     ω5 = 2π * ωJ32 - 7Γ
#     ω6 = 2π * ωJ32 - 8Γ
#     ω7 = 2π * ωJ32 - 9Γ
#     ω8 = 2π * ωJ32 - 10Γ
    
    lasers_tuple11 = [(ωJ12 - Γ, ϵJ12, s/60), (ωJ12 - 2Γ, ϵJ12, s/40), (ωJ12 - 3Γ, ϵJ12, s/30), (ωJ12 - 5Γ, ϵJ12, s/5), (ωJ12 - 7Γ, ϵJ12, s), (ωJ12 - 9Γ, ϵJ12, 2s), (ωJ12 - 11Γ, ϵJ12, 4s)]
    lasers_tuple12 = [(ωJ32 - Γ, ϵJ32, s/60), (ωJ12 - 2Γ, ϵJ32, s/40), (ωJ32 - 3Γ, ϵJ32, s/30), (ωJ32 - 5Γ, ϵJ32, s/5), (ωJ32 - 7Γ, ϵJ32, s), (ωJ32 - 9Γ, ϵJ32, 2s), (ωJ32 - 11Γ, ϵJ32, 4s)]
    
    lasers_tuple1 = [lasers_tuple11; lasers_tuple12]
    
    # lasers_tuple1 = [
    #     (ω1, ϵJ12, s1),
    #     (ω2, ϵJ12, s2),
    #     (ω3, ϵJ12, s3),
    #     (ω4, ϵJ12, s4),
    #     (ω5, ϵJ32, s5),
    #     (ω6, ϵJ32, s6),
    #     (ω7, ϵJ32, s7),
    #     (ω8, ϵJ32, s8)
    # ]

    include("define_lasers_updated.jl")
    lasers1 = define_lasers(
        sim_params.RF_frequency,
        lasers_tuple1
    )
    
#     ## Define a "slowing" beam going against x + y
#     # J=1/2 components
#     s1 = s/8
#     s2 = s/8
#     s3 = s/8
#     s4 = s/8
#     ω1 = 2π * (energy(states[end]) - energy(states[1])) - 7Γ
#     ω2 = 2π * (energy(states[end]) - energy(states[1])) - 8Γ
#     ω3 = 2π * (energy(states[end]) - energy(states[1])) - 9Γ
#     ω4 = 2π * (energy(states[end]) - energy(states[1])) - 10Γ

#     # J=3/2 components
#     s5 = s/8
#     s6 = s/8
#     s7 = s/8
#     s8 = s/8
#     ω5 = 2π * (energy(states[end]) - energy(states[5])) - 7Γ
#     ω6 = 2π * (energy(states[end]) - energy(states[5])) - 8Γ
#     ω7 = 2π * (energy(states[end]) - energy(states[5])) - 9Γ
#     ω8 = 2π * (energy(states[end]) - energy(states[5])) - 10Γ
    
#     lasers_tuple2 = [
#         (ω1, ϵJ32, s1),
#         (ω2, ϵJ32, s2),
#         (ω3, ϵJ32, s3),
#         (ω4, ϵJ32, s4),
#         (ω5, ϵJ12, s5),
#         (ω6, ϵJ12, s6),
#         (ω7, ϵJ12, s7),
#         (ω8, ϵJ12, s8)
#     ]
    
    # lasers_tuple21 = [(ωJ12 - i*Γ, ϵJ32, s/20) for i ∈ 2:2:12]
    # lasers_tuple22 = [(ωJ32 - i*Γ, ϵJ12, s/20) for i ∈ 2:2:12]
    
    lasers_tuple21 = [(ωJ12 - Γ, ϵJ32, s/60), (ωJ12 - 2Γ, ϵJ32, s/40), (ωJ12 - 3Γ, ϵJ32, s/30), (ωJ12 - 5Γ, ϵJ32, s/20), (ωJ12 - 7Γ, ϵJ32, s/10), (ωJ12 - 7Γ, ϵJ32, 2s), (ωJ12 - 7Γ, ϵJ32, 2s)]
    lasers_tuple22 = [(ωJ32 - Γ, ϵJ12, s/60), (ωJ12 - 2Γ, ϵJ12, s/40), (ωJ32 - 3Γ, ϵJ12, s/30), (ωJ32 - 5Γ, ϵJ12, s/20), (ωJ32 - 7Γ, ϵJ12, s/10), (ωJ32 - 7Γ, ϵJ12, 2s), (ωJ32 - 7Γ, ϵJ12, 2s)]
    
    # lasers_tuple21 = [(ωJ12 - i*Γ, SVector{3,ComplexF64}(0,1,0), s/30) for i ∈ 2:2:10]
    # lasers_tuple22 = [(ωJ32 - i*Γ, SVector{3,ComplexF64}(0,1,0), s/30) for i ∈ 2:2:10]
    
    lasers_tuple2 = [lasers_tuple21; lasers_tuple22]
    
    # include("define_lasers_updated.jl")
    lasers2 = define_lasers(
        sim_params.RF_frequency,
        lasers_tuple2
    )
    
    lasers = lasers1
    # lasers = [lasers1; lasers2]
    lasers = convert(Vector{Field{Float64, typeof(lasers[1].ϵ), typeof(lasers[1].s_func)}}, lasers)
    
end

# %% [markdown]
# ### Define Zeeman Hamiltonian

# %%
@everywhere include("define_zeeman_hamiltonian.jl")
;

# %% [markdown]
# ### Run simulation

# %%
# ts = 1e-3 .* (0:0.00001:0.002) / (1/Γ)
# pols = zeros(length(ts))
# fields = zeros(length(ts))

# for (i,t) ∈ enumerate(ts)
#     pol = iseven(t ÷ (π/sim_params.RF_frequency)) ? +1 : -1
#     field = cos(sim_params.RF_frequency * t + π/2)
#     pols[i] = pol
#     fields[i] = field
# end

# plot(ts * (1/Γ), pols)
# plot!(ts * (1/Γ), fields)

# %%
@everywhere function update_H_and_∇H(H, p, r, t)
    
    # Define a ramping magnetic field
    Zeeman_Hz = p.extra_data.Zeeman_Hz
    Zeeman_Hx = p.extra_data.Zeeman_Hx
    Zeeman_Hy = p.extra_data.Zeeman_Hy
    
    scalar = cos(p.sim_params.RF_frequency * t + π/2)
    
    gradient_x = +scalar * p.sim_params.B_gradient * 1e2 / k / 2
    gradient_y = +scalar * p.sim_params.B_gradient * 1e2 / k / 2
    gradient_z = -scalar * p.sim_params.B_gradient * 1e2 / k
    
    Bx = gradient_x * r[1] + p.sim_params.B_offset[1]
    By = gradient_y * r[2] + p.sim_params.B_offset[2]
    Bz = gradient_z * r[3] + p.sim_params.B_offset[3]
    
    @turbo for i in eachindex(H)
        H.re[i] = Bz * Zeeman_Hz.re[i] + Bx * Zeeman_Hx.re[i] + By * Zeeman_Hy.re[i]
        H.im[i] = Bz * Zeeman_Hz.im[i] + Bx * Zeeman_Hx.im[i] + By * Zeeman_Hy.im[i]
    end
    
    ∇H = SVector{3, Float64}(0,0,0)
    
    return ∇H
end
;

# %%
@everywhere extra_data = MutableNamedTuple(
    Zeeman_Hx = Zeeman_x_mat,
    Zeeman_Hy = Zeeman_y_mat,
    Zeeman_Hz = Zeeman_z_mat
)
;

# %%
t_start = 0.0
t_end   = 10e-3
t_span  = (t_start, t_end) ./ (1/Γ)

n_states = length(states)
n_excited = 4

r0 = [-0.03, -0.03, 0] / √2
v0 = [30, 30, 0] / √2
particle = Particle()
particle.r = r0 ./ (1/k)
particle.v = v0 ./ (Γ/k)
ψ₀ = zeros(ComplexF64, n_states)
ψ₀[1] = 1.0

using Logging: global_logger
using TerminalLoggers: TerminalLogger
global_logger(TerminalLogger())

p = schrodinger_stochastic(particle, states, lasers, d, ψ₀, m/(ħ*k^2/Γ), n_excited; sim_params=sim_params, extra_data=extra_data, λ=λ, Γ=Γ, update_H_and_∇H=update_H_and_∇H)
prob = ODEProblem(ψ_stochastic_potential!, p.ψ, t_span, p)

cb = ContinuousCallback(condition_simple, SE_collapse_pol_always!, nothing, save_positions=(false,false))
@time sol = DifferentialEquations.solve(prob, alg=DP5(), reltol=5e-4, callback=cb, saveat=1000, maxiters=80000000, progress=true, progress_steps=200000)
;
# Out:
# ODE   0%|█                                              |  ETA: N/A
# ODE   5%|███                                            |  ETA: 0:01:19
# ODE   9%|█████                                          |  ETA: 0:01:24
# ODE  13%|███████                                        |  ETA: 0:01:25
# ODE  17%|████████                                       |  ETA: 0:01:24
# ODE  21%|██████████                                     |  ETA: 0:01:21
# ODE  24%|████████████                                   |  ETA: 0:01:18
# ODE  28%|██████████████                                 |  ETA: 0:01:14
# ODE  32%|████████████████                               |  ETA: 0:01:11
# ODE  36%|█████████████████                              |  ETA: 0:01:08
# ODE  39%|███████████████████                            |  ETA: 0:01:05
# ODE  43%|█████████████████████                          |  ETA: 0:01:02
# ODE  46%|██████████████████████                         |  ETA: 0:00:59
# ODE  50%|████████████████████████                       |  ETA: 0:00:54
# ODE  56%|███████████████████████████                    |  ETA: 0:00:47
# ODE  61%|█████████████████████████████                  |  ETA: 0:00:41
# ODE  65%|███████████████████████████████                |  ETA: 0:00:36
# ODE  70%|█████████████████████████████████              |  ETA: 0:00:32
# ODE  74%|███████████████████████████████████            |  ETA: 0:00:28
# ODE  78%|█████████████████████████████████████          |  ETA: 0:00:24
# ODE  81%|███████████████████████████████████████        |  ETA: 0:00:20
# ODE  85%|████████████████████████████████████████       |  ETA: 0:00:17
# ODE  88%|██████████████████████████████████████████     |  ETA: 0:00:13
# ODE  92%|████████████████████████████████████████████   |  ETA: 0:00:09
# ODE  95%|█████████████████████████████████████████████  |  ETA: 0:00:06
# ODE  98%|██████████████████████████████████████████████ |  ETA: 0:00:03
# 115.450983 seconds (9.34 k allocations: 996.266 KiB)
# ODE 100%|███████████████████████████████████████████████| Time: 0:01:55

# %%
plot_us = sol.u
plot_ts = sol.t

x_trajectories = [real(u[n_states + n_excited + 1]) for u in plot_us] ./ k*1e3
y_trajectories = [real(u[n_states + n_excited + 2]) for u in plot_us] ./ k*1e3
z_trajectories = [real(u[n_states + n_excited + 3]) for u in plot_us] ./ k*1e3
x_velocities = [real(u[n_states + n_excited + 4]) for u in plot_us] .* (Γ/k)
y_velocities = [real(u[n_states + n_excited + 5]) for u in plot_us] .* (Γ/k)
z_velocities = [real(u[n_states + n_excited + 6]) for u in plot_us] .* (Γ/k)
velocities = [[vx,vy,vz] for (vx,vy,vz) ∈ zip(x_velocities, y_velocities, z_velocities)]

excited_population = real.([sum(conj(u[i]) * u[i] for i ∈ 13:16) for u in plot_us])
;

# %%
plot(sol.t .* (1e3/Γ), (x_trajectories .+ y_trajectories) ./ √2,
    legend=nothing,
    xlabel="Time (ms)",
    ylabel="z position (mm)",
    ylim=(-40,25)
)

# %%
plot(sol.t .* (1e3/Γ), (x_velocities .+ y_velocities) ./ √2,
    legend=nothing,
    xlabel="Time (ms)",
    ylabel="Velocity (m/s)"
)

# %%
moving_average(vs,n) = [sum(@view vs[i:(i+n-1)])/n for i in 1:(length(vs)-(n-1))]

plot(sol.t[1:end-9] .* (1e3/Γ), moving_average(Γ * excited_population, 10),
    legend=nothing,
    xlabel="Time (ms)",
    ylabel="z position (mm)",
    ylim=(0,1.2e7)
)

# %%
prob.p.n_scatters ./ 5e-3
# Out:
# 3.1994e6

# %%
exp(-50/16) / exp(-100/16)
# Out:
# 22.75989509352673

# %%
exp(-72/16)
# Out:
# 0.011108996538242306

# %% [markdown]
# ### Run simulation for multiple particles in parallel

# %%
@everywhere begin
    vs = 2:1:22
    const scan_params = (
        v = vs,
        )
end
;

# %%
@everywhere function prob_func(prob, i, repeat)

    sim_params = prob.p.sim_params
    extra_data = prob.p.extra_data
    n_states = prob.p.n_states
    n_excited = prob.p.n_excited
    t_span = prob.tspan
    
    X_states, A_states = define_CaOH_states()
    states = [X_states; A_states[1:4]]
    d = tdms_between_states(states, states)
    
    lasers = define_lasers(
        states,
        sim_params.RF_frequency,
        sim_params.s1,
        sim_params.s2,
        sim_params.s3,
        sim_params.s4,
        sim_params.Δ1,
        sim_params.Δ2,
        sim_params.Δ3,
        sim_params.Δ4,
        sim_params.pol1_x,
        sim_params.pol2_x,
        sim_params.pol3_x,
        sim_params.pol4_x,
        sim_params.pol_imbalance,
        sim_params.s_imbalance,
        sim_params.retro_loss,
        sim_params.off_center,
        sim_params.pointing_error
    )

    # Define initial conditions for the molecule
    v = scan_params.v[i]
    r0 = [-0.02, -0.02, 0] / √2
    v0 = v .* [1, 1, 0] / √2
    particle = Particle()
    particle.r = r0 ./ (1/k)
    particle.v = v0 ./ (Γ/k)
    ψ₀ = zeros(ComplexF64, n_states)
    ψ₀[1] = 1.0
    
    p = schrodinger_stochastic(particle, states, lasers, d, ψ₀, m/(ħ*k^2/Γ), n_excited; sim_params=sim_params, extra_data=extra_data, λ=λ, Γ=Γ, update_H_and_∇H=update_H_and_∇H)
    callback = ContinuousCallback(condition_simple, SE_collapse_pol_always!, nothing, save_positions=(false,false))
    prob = ODEProblem(ψ_stochastic_potential!, p.ψ, t_span, p, callback=callback, reltol=5e-4, saveat=1000, maxiters=80000000)

    return prob
end
;

# %%
n_molecules = length(vs)
ensemble_prob = EnsembleProblem(prob; prob_func=prob_func)
@time ensemble_sol = solve(ensemble_prob, DP5(), EnsembleDistributed(); trajectories=n_molecules)
;
# Out:
# UndefVarError: `prob_func` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[2461]:2

# %%
function captured(sol)
    xy_pos = (sol.u[end][n_states + n_excited + 1] + sol.u[end][n_states + n_excited + 2]) / √2 / k*1e3
    if real(xy_pos) > 10
        return false
    end
    return true
end

function capture_velocity(vs, ensemble_sol)
    max_idx = maximum(findall([captured(ensemble_sol[i]) for i ∈ eachindex(vs)]))
    return vs[max_idx]
end
;

# %%
x_trajectories = Array{Vector{Float64}}(fill([],n_molecules))
y_trajectories = Array{Vector{Float64}}(fill([],n_molecules)) 
z_trajectories = Array{Vector{Float64}}(fill([],n_molecules))
x_velocities = Array{Vector{Float64}}(fill([],n_molecules))
y_velocities = Array{Vector{Float64}}(fill([],n_molecules))
z_velocities = Array{Vector{Float64}}(fill([],n_molecules))
photons_scattered = zeros(n_molecules)

times = Array{Vector{Float64}}(fill([],n_molecules))

for i ∈ 1:n_molecules
    sol_u = ensemble_sol[i].u
    sol_t = ensemble_sol[i].t
    
    x_trajectories[i] = [x_trajectories[i]; [real(u[n_states + n_excited + 1]) for u in sol_u] ./ k*1e3]
    y_trajectories[i] = [y_trajectories[i]; [real(u[n_states + n_excited + 2]) for u in sol_u] ./ k*1e3]
    z_trajectories[i] = [z_trajectories[i]; [real(u[n_states + n_excited + 3]) for u in sol_u] ./ k*1e3]
    
    x_velocities[i] = [x_velocities[i]; [real(u[n_states + n_excited + 4]) for u in sol_u] ./ (k/Γ)]
    y_velocities[i] = [y_velocities[i]; [real(u[n_states + n_excited + 5]) for u in sol_u] ./ (k/Γ)]
    z_velocities[i] = [z_velocities[i]; [real(u[n_states + n_excited + 6]) for u in sol_u] ./ (k/Γ)]
    
    photons_scattered[i] = ensemble_sol[i].prob.p.n_scatters
    
    times[i] = sol_t .* (1/Γ)
end

trajectories = [
    [[x[1],x[2],x[3]] for x ∈ zip(x_trajectories[i], y_trajectories[i], z_trajectories[i])] 
    for i ∈ 1:n_molecules
    ]
;
# Out:
# UndefVarError: `ensemble_sol` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[2463]:12

# %%
lim = 40
plot()
for i ∈ 1:n_molecules
    plot!(times[i] .* 1e3, (x_trajectories[i] .+ y_trajectories[i]) ./ √2, legend=nothing)
end
plot!(ylim=(-40,20))

# %%
Δ1s = (-4:0.2:0) .* Γ
Δ2s = (-4:0.2:0) .* Γ

capture_vs = zeros(Float64, length(Δ1s), length(Δ2s))
ensemble_sols = Dict()

for (i,Δ1) ∈ enumerate(Δ1s)
    for (j,Δ2) ∈ enumerate(Δ2s)
        
        # set detunings
        prob.p.sim_params.Δ1 = Δ1
        prob.p.sim_params.Δ2 = Δ2
        
        # solve the problem for a range of velocities
        n_molecules = length(vs)
        ensemble_prob = EnsembleProblem(prob; prob_func=prob_func)
        @time ensemble_sol = solve(ensemble_prob, DP5(), EnsembleDistributed(); trajectories=n_molecules)
        
        # calculate capture velocity
        capture_vs[i,j] = capture_velocity(vs, ensemble_sol)
        ensemble_sols[(Δ1,Δ2)] = ensemble_sol
    end
end
# Out:
#  84.206990 seconds (602.38 k allocations: 24.314 MiB, 0.02% gc time)
#  85.860194 seconds (603.22 k allocations: 24.409 MiB)
#  87.812146 seconds (608.28 k allocations: 24.597 MiB, 0.02% gc time)
#  90.417420 seconds (610.23 k allocations: 24.723 MiB)
#  97.874729 seconds (618.32 k allocations: 25.138 MiB, 0.02% gc time)
#  99.891759 seconds (619.05 k allocations: 25.268 MiB, 0.02% gc time)
# 111.290194 seconds (624.26 k allocations: 25.653 MiB)
# 115.067271 seconds (639.46 k allocations: 26.186 MiB, 0.01% gc time)
# 127.411631 seconds (640.71 k allocations: 26.642 MiB)
# 126.746806 seconds (650.73 k allocations: 27.042 MiB, 0.01% gc time)
# 142.378006 seconds (661.18 k allocations: 27.518 MiB, 0.01% gc time)
# 136.910335 seconds (660.23 k allocations: 27.442 MiB)
# 143.526452 seconds (666.00 k allocations: 27.745 MiB, 0.01% gc time)
# 146.762426 seconds (666.07 k allocations: 27.775 MiB, 0.01% gc time)
# 142.626914 seconds (665.07 k allocations: 27.584 MiB)
# 138.961208 seconds (661.13 k allocations: 27.508 MiB, 0.01% gc time)
# 134.179195 seconds (659.84 k allocations: 27.381 MiB)
# 129.001138 seconds (659.67 k allocations: 27.228 MiB, 0.01% gc time)
# 132.382180 seconds (655.07 k allocations: 27.025 MiB, 0.01% gc time)
# 130.165254 seconds (649.15 k allocations: 26.737 MiB)
# 125.355782 seconds (640.00 k allocations: 26.304 MiB, 0.01% gc time)
#  87.867418 seconds (602.72 k allocations: 24.337 MiB)
#  86.763737 seconds (604.65 k allocations: 24.434 MiB, 0.02% gc time)
#  87.511460 seconds (605.79 k allocations: 24.585 MiB, 0.01% gc time)
#  88.323842 seconds (608.03 k allocations: 24.671 MiB)
#  94.418529 seconds (613.87 k allocations: 24.977 MiB, 0.01% gc time)
# 101.500729 seconds (618.29 k allocations: 25.128 MiB)
# 109.437027 seconds (629.23 k allocations: 25.650 MiB, 0.01% gc time)
# 116.512184 seconds (636.04 k allocations: 26.056 MiB)
# 126.048183 seconds (640.79 k allocations: 26.584 MiB, 0.01% gc time)
# 128.539337 seconds (650.82 k allocations: 26.985 MiB, 0.01% gc time)
# 143.338444 seconds (660.62 k allocations: 27.424 MiB)
# 144.432583 seconds (666.14 k allocations: 27.703 MiB, 0.01% gc time)
# 146.394028 seconds (667.23 k allocations: 27.782 MiB, 0.01% gc time)
# 144.769665 seconds (665.28 k allocations: 27.621 MiB)
# 148.195058 seconds (666.44 k allocations: 27.731 MiB, 0.01% gc time)
# 139.094123 seconds (664.84 k allocations: 27.561 MiB)
# 143.191065 seconds (669.05 k allocations: 27.857 MiB, 0.01% gc time, 0.00% compilation time)
# 133.984207 seconds (660.76 k allocations: 27.409 MiB, 0.01% gc time)
# 130.252335 seconds (654.93 k allocations: 27.147 MiB)
# 127.945821 seconds (650.50 k allocations: 26.921 MiB, 0.01% gc time)
# 126.164811 seconds (646.71 k allocations: 26.612 MiB, 0.01% gc time)
#  86.142698 seconds (607.21 k allocations: 24.525 MiB)
#  84.818232 seconds (603.62 k allocations: 24.435 MiB, 0.01% gc time)
#  86.733237 seconds (607.40 k allocations: 24.560 MiB)
#  89.074367 seconds (608.74 k allocations: 24.721 MiB, 0.01% gc time)
#  94.431736 seconds (613.29 k allocations: 24.894 MiB)
# 100.805044 seconds (618.99 k allocations: 25.301 MiB, 0.01% gc time)
# 107.202637 seconds (624.42 k allocations: 25.570 MiB, 0.01% gc time)
# 114.574449 seconds (634.07 k allocations: 26.004 MiB)
# 125.607662 seconds (649.40 k allocations: 26.675 MiB, 0.01% gc time)
# 129.293884 seconds (652.69 k allocations: 27.214 MiB)
# 144.907554 seconds (663.73 k allocations: 27.634 MiB, 0.01% gc time)
# 145.499597 seconds (666.20 k allocations: 27.777 MiB, 0.01% gc time)
# 150.431859 seconds (670.54 k allocations: 27.903 MiB)
# 159.362971 seconds (671.60 k allocations: 27.987 MiB, 0.01% gc time)
# 158.071045 seconds (671.64 k allocations: 28.002 MiB, 0.01% gc time)
# 146.152013 seconds (665.82 k allocations: 27.762 MiB)
# 144.887355 seconds (666.25 k allocations: 27.774 MiB, 0.01% gc time)
# 134.356300 seconds (660.25 k allocations: 27.450 MiB)
# 127.735288 seconds (655.81 k allocations: 27.244 MiB, 0.01% gc time)
# 128.432925 seconds (655.49 k allocations: 27.115 MiB, 0.01% gc time)
# 125.354924 seconds (649.26 k allocations: 26.717 MiB)
#  86.287674 seconds (605.82 k allocations: 24.503 MiB, 0.01% gc time)
#  87.133234 seconds (603.23 k allocations: 24.508 MiB)
#  86.780208 seconds (603.93 k allocations: 24.553 MiB, 0.02% gc time)
#  87.217151 seconds (608.50 k allocations: 24.688 MiB, 0.01% gc time)
#  93.027099 seconds (612.98 k allocations: 24.838 MiB)
#  97.763299 seconds (619.03 k allocations: 25.257 MiB, 0.01% gc time)
# 108.416954 seconds (623.70 k allocations: 25.506 MiB)
# 114.671016 seconds (630.65 k allocations: 26.080 MiB, 0.01% gc time)
# 127.449969 seconds (640.00 k allocations: 26.450 MiB)
# 127.197070 seconds (655.43 k allocations: 27.179 MiB, 0.01% gc time)
# 140.727508 seconds (661.22 k allocations: 27.531 MiB, 0.01% gc time)
# 148.386749 seconds (665.85 k allocations: 27.768 MiB)
# 148.504867 seconds (666.60 k allocations: 27.771 MiB, 0.01% gc time)
# 154.247350 seconds (671.61 k allocations: 28.009 MiB, 0.01% gc time)
# 159.923227 seconds (671.10 k allocations: 27.957 MiB)
# 149.900649 seconds (671.10 k allocations: 27.929 MiB, 0.01% gc time)
# 145.673452 seconds (666.24 k allocations: 27.783 MiB, 0.01% gc time)
# 143.027237 seconds (665.28 k allocations: 27.619 MiB)
# 135.428683 seconds (665.49 k allocations: 27.610 MiB, 0.01% gc time)
# 126.894859 seconds (656.64 k allocations: 27.194 MiB)
# 124.771851 seconds (654.82 k allocations: 27.008 MiB, 0.01% gc time)
#  88.071155 seconds (608.33 k allocations: 24.650 MiB, 0.01% gc time)
#  88.657624 seconds (607.85 k allocations: 24.634 MiB)
#  87.455557 seconds (608.57 k allocations: 24.681 MiB, 0.01% gc time)
#  87.849141 seconds (605.15 k allocations: 24.580 MiB)
#  89.568581 seconds (608.92 k allocations: 24.810 MiB, 0.01% gc time)
#  96.911562 seconds (613.64 k allocations: 25.010 MiB)
# 107.890257 seconds (624.20 k allocations: 25.516 MiB, 0.01% gc time)
# 118.332367 seconds (630.71 k allocations: 26.080 MiB, 0.01% gc time)
# 124.418932 seconds (639.99 k allocations: 26.457 MiB)
# 128.202851 seconds (655.44 k allocations: 27.116 MiB, 0.01% gc time)
# 133.987991 seconds (660.02 k allocations: 27.357 MiB)
# 146.494543 seconds (670.80 k allocations: 27.895 MiB, 0.01% gc time)
# 155.806401 seconds (671.63 k allocations: 28.006 MiB, 0.01% gc time)
# 156.967061 seconds (670.98 k allocations: 27.956 MiB)
# 152.270905 seconds (671.38 k allocations: 27.979 MiB, 0.01% gc time)
# 152.957009 seconds (671.39 k allocations: 27.977 MiB, 0.01% gc time)
# 142.147863 seconds (665.26 k allocations: 27.620 MiB)
# 144.576088 seconds (670.59 k allocations: 27.862 MiB, 0.01% gc time)
# 141.786529 seconds (665.85 k allocations: 27.662 MiB, 0.01% gc time)
# 130.307405 seconds (659.77 k allocations: 27.315 MiB)
# 131.080827 seconds (660.63 k allocations: 27.386 MiB, 0.01% gc time)
#  92.661226 seconds (608.53 k allocations: 24.813 MiB)
#  90.214500 seconds (608.85 k allocations: 24.727 MiB, 0.01% gc time)
#  91.631269 seconds (613.11 k allocations: 24.895 MiB, 0.01% gc time)
#  92.079168 seconds (608.47 k allocations: 24.786 MiB)
#  92.436527 seconds (609.13 k allocations: 24.829 MiB, 0.01% gc time)
# 107.449800 seconds (613.93 k allocations: 25.017 MiB)
# 103.674119 seconds (619.38 k allocations: 25.369 MiB, 0.01% gc time)
# 110.748655 seconds (627.60 k allocations: 25.836 MiB)
# 116.837746 seconds (639.89 k allocations: 26.401 MiB, 0.01% gc time)
# 125.607152 seconds (650.87 k allocations: 27.007 MiB, 0.01% gc time)
# 140.280950 seconds (664.92 k allocations: 27.572 MiB)
# 147.663997 seconds (668.83 k allocations: 27.892 MiB, 0.01% gc time)
# 149.019043 seconds (671.08 k allocations: 27.948 MiB, 0.01% gc time)
# 149.186700 seconds (670.52 k allocations: 27.908 MiB)
# 162.863912 seconds (671.98 k allocations: 28.095 MiB, 0.01% gc time)
# 153.995099 seconds (670.78 k allocations: 27.935 MiB)
# 154.024876 seconds (671.40 k allocations: 27.972 MiB, 0.01% gc time)
# 142.831988 seconds (666.00 k allocations: 27.679 MiB, 0.01% gc time)
# 140.655735 seconds (665.22 k allocations: 27.619 MiB)
# 132.806089 seconds (665.23 k allocations: 27.582 MiB, 0.01% gc time)
# 128.089547 seconds (660.45 k allocations: 27.375 MiB, 0.01% gc time)
#  94.382014 seconds (608.89 k allocations: 24.859 MiB)
#  96.421875 seconds (614.20 k allocations: 25.034 MiB, 0.01% gc time)
#  95.628418 seconds (611.05 k allocations: 25.004 MiB)
#  94.408938 seconds (613.91 k allocations: 24.990 MiB, 0.01% gc time)
#  96.420783 seconds (613.50 k allocations: 24.988 MiB)
#  96.013127 seconds (613.99 k allocations: 25.059 MiB, 0.01% gc time)
# 101.574192 seconds (623.58 k allocations: 25.439 MiB, 0.01% gc time)
# 111.995363 seconds (628.10 k allocations: 25.734 MiB)
# 116.992927 seconds (638.30 k allocations: 26.356 MiB, 0.01% gc time)
# 125.348261 seconds (650.25 k allocations: 27.029 MiB)
# 131.143906 seconds (660.44 k allocations: 27.422 MiB, 0.01% gc time)
# 143.189067 seconds (663.52 k allocations: 27.696 MiB, 0.01% gc time)
# 155.092917 seconds (670.90 k allocations: 27.948 MiB)
# 155.873011 seconds (671.73 k allocations: 28.027 MiB, 0.01% gc time)
# 160.938215 seconds (671.80 k allocations: 28.021 MiB, 0.01% gc time)
# 154.233585 seconds (670.68 k allocations: 27.913 MiB)
# 182.640939 seconds (677.09 k allocations: 28.234 MiB, 0.01% gc time)
# 143.145739 seconds (666.06 k allocations: 27.759 MiB, 0.01% gc time)
# 142.832049 seconds (665.45 k allocations: 27.650 MiB)
# 128.319254 seconds (665.18 k allocations: 27.569 MiB, 0.01% gc time)
# 129.483662 seconds (659.81 k allocations: 27.324 MiB)
# 100.437629 seconds (614.90 k allocations: 25.156 MiB, 0.02% gc time)
#  98.478546 seconds (614.55 k allocations: 25.162 MiB, 0.01% gc time)
#  99.267888 seconds (613.92 k allocations: 25.114 MiB)
# 102.231673 seconds (619.07 k allocations: 25.253 MiB, 0.01% gc time)
#  99.175670 seconds (618.42 k allocations: 25.228 MiB)
# 100.587502 seconds (616.22 k allocations: 25.389 MiB, 0.01% gc time)
# 100.931801 seconds (618.48 k allocations: 25.236 MiB)
# 107.898069 seconds (628.98 k allocations: 25.741 MiB, 0.01% gc time)
# 115.525395 seconds (639.73 k allocations: 26.379 MiB, 0.01% gc time)
# 121.880875 seconds (647.08 k allocations: 26.831 MiB)
# 128.507877 seconds (660.30 k allocations: 27.350 MiB, 0.01% gc time)
# 140.065273 seconds (665.61 k allocations: 27.654 MiB, 0.01% gc time)
# 155.857533 seconds (670.96 k allocations: 27.956 MiB)
# 153.319312 seconds (671.51 k allocations: 27.985 MiB, 0.01% gc time)
# 163.349590 seconds (671.34 k allocations: 28.058 MiB)
# 151.226071 seconds (671.34 k allocations: 27.971 MiB, 0.01% gc time)
# 151.773023 seconds (671.31 k allocations: 27.961 MiB, 0.01% gc time)
# 144.231259 seconds (669.93 k allocations: 27.814 MiB)
# 140.915372 seconds (665.99 k allocations: 27.677 MiB, 0.01% gc time)
# 141.325064 seconds (665.71 k allocations: 27.628 MiB, 0.01% gc time)
# 126.012540 seconds (659.72 k allocations: 27.320 MiB)
# 110.569360 seconds (624.63 k allocations: 25.582 MiB, 0.01% gc time)
# 109.018780 seconds (623.67 k allocations: 25.495 MiB)
# 108.223107 seconds (621.95 k allocations: 25.510 MiB, 0.01% gc time)
# 105.289602 seconds (621.19 k allocations: 25.578 MiB, 0.01% gc time)
# 105.794154 seconds (621.34 k allocations: 25.454 MiB)
# 106.182514 seconds (624.20 k allocations: 25.521 MiB, 0.01% gc time)
# 106.179490 seconds (623.55 k allocations: 25.613 MiB)
# 108.896278 seconds (626.73 k allocations: 25.717 MiB, 0.01% gc time)
# 112.880942 seconds (639.21 k allocations: 26.386 MiB, 0.01% gc time)
# 125.484950 seconds (649.80 k allocations: 26.885 MiB)
# 132.392220 seconds (660.90 k allocations: 27.492 MiB, 0.01% gc time)
# 140.880556 seconds (660.71 k allocations: 27.510 MiB)
# 146.111071 seconds (666.47 k allocations: 27.819 MiB, 0.01% gc time)
# 146.786289 seconds (666.49 k allocations: 27.815 MiB, 0.01% gc time)
# 152.608141 seconds (670.74 k allocations: 27.931 MiB)
# 146.544238 seconds (670.92 k allocations: 27.915 MiB, 0.01% gc time)
# 154.570386 seconds (671.39 k allocations: 27.968 MiB, 0.01% gc time)
# 145.781774 seconds (670.09 k allocations: 27.830 MiB)
# 142.112999 seconds (665.96 k allocations: 27.667 MiB, 0.01% gc time)
# 138.948248 seconds (665.00 k allocations: 27.583 MiB)
# 129.405415 seconds (665.08 k allocations: 27.558 MiB, 0.01% gc time)
# 114.394226 seconds (630.22 k allocations: 25.941 MiB, 0.01% gc time)
# 115.475138 seconds (629.09 k allocations: 25.807 MiB)
# 112.571112 seconds (623.93 k allocations: 25.733 MiB, 0.01% gc time)
# 114.038206 seconds (627.49 k allocations: 25.836 MiB)
# 114.357410 seconds (634.27 k allocations: 26.036 MiB, 0.01% gc time)
# 114.592160 seconds (638.99 k allocations: 26.311 MiB, 0.01% gc time)
# 111.144242 seconds (633.64 k allocations: 26.062 MiB)
# 111.833988 seconds (633.18 k allocations: 26.058 MiB, 0.01% gc time)
# 113.793321 seconds (635.97 k allocations: 26.170 MiB)
# 125.148100 seconds (652.13 k allocations: 26.955 MiB, 0.01% gc time)
# 125.087731 seconds (660.08 k allocations: 27.324 MiB, 0.01% gc time)
# 138.510081 seconds (660.55 k allocations: 27.490 MiB)
# 138.749514 seconds (665.63 k allocations: 27.637 MiB, 0.01% gc time)
# 144.323885 seconds (666.17 k allocations: 27.709 MiB, 0.01% gc time)
# 146.378425 seconds (670.10 k allocations: 27.839 MiB)
# 144.818160 seconds (670.94 k allocations: 27.913 MiB, 0.01% gc time)
# 144.235631 seconds (665.88 k allocations: 27.761 MiB, 0.01% gc time)
# 139.691051 seconds (665.26 k allocations: 27.629 MiB)
# 141.143886 seconds (665.97 k allocations: 27.666 MiB, 0.01% gc time)
# 139.105190 seconds (665.00 k allocations: 27.578 MiB)
# 125.718672 seconds (660.21 k allocations: 27.336 MiB, 0.01% gc time)
# 128.808662 seconds (640.31 k allocations: 26.426 MiB, 0.01% gc time)
# 121.614217 seconds (634.98 k allocations: 26.202 MiB)
# 120.079734 seconds (635.72 k allocations: 26.329 MiB, 0.01% gc time)
# 118.040745 seconds (638.82 k allocations: 26.279 MiB)
# 119.099459 seconds (644.37 k allocations: 26.548 MiB, 0.01% gc time)
# 118.755469 seconds (644.59 k allocations: 26.596 MiB, 0.01% gc time)
# 119.239232 seconds (643.92 k allocations: 26.548 MiB)
# 114.199822 seconds (642.02 k allocations: 26.449 MiB, 0.01% gc time)
# 118.016679 seconds (644.34 k allocations: 26.621 MiB)
# 123.533281 seconds (645.53 k allocations: 26.742 MiB, 0.01% gc time)
# 122.776245 seconds (652.83 k allocations: 27.123 MiB, 0.01% gc time)
# 138.049564 seconds (662.00 k allocations: 27.471 MiB)
# 145.680271 seconds (666.07 k allocations: 27.677 MiB, 0.01% gc time)
# 147.534974 seconds (666.13 k allocations: 27.685 MiB, 0.01% gc time)
# 148.359697 seconds (665.83 k allocations: 27.748 MiB)
# 142.604581 seconds (666.13 k allocations: 27.698 MiB, 0.01% gc time)
# 145.152629 seconds (665.59 k allocations: 27.727 MiB)
# 143.542044 seconds (665.94 k allocations: 27.654 MiB, 0.01% gc time)
# 151.872665 seconds (666.07 k allocations: 27.647 MiB, 0.01% gc time)
# 139.347548 seconds (664.69 k allocations: 27.517 MiB)
# 137.702033 seconds (660.55 k allocations: 27.344 MiB, 0.01% gc time)
# 139.030560 seconds (646.12 k allocations: 26.722 MiB, 0.01% gc time)
# 137.229127 seconds (645.15 k allocations: 26.631 MiB)
# 140.024943 seconds (646.28 k allocations: 26.800 MiB, 0.01% gc time)
# 140.530390 seconds (649.74 k allocations: 26.809 MiB)
# 138.169882 seconds (650.72 k allocations: 26.981 MiB, 0.01% gc time)
# 136.382858 seconds (648.29 k allocations: 26.950 MiB, 0.01% gc time)
# 135.711397 seconds (650.06 k allocations: 26.944 MiB)
# 135.503535 seconds (655.41 k allocations: 27.130 MiB, 0.02% gc time)
# 136.221123 seconds (655.36 k allocations: 27.062 MiB, 0.01% gc time)
# 131.053824 seconds (654.72 k allocations: 27.103 MiB)
# 131.810816 seconds (655.34 k allocations: 27.063 MiB, 0.01% gc time)
# 134.070094 seconds (659.77 k allocations: 27.290 MiB)
# 135.967582 seconds (665.41 k allocations: 27.592 MiB, 0.01% gc time)
# 150.517602 seconds (666.21 k allocations: 27.676 MiB, 0.01% gc time)
# 139.562531 seconds (660.42 k allocations: 27.454 MiB)
# 147.615402 seconds (666.14 k allocations: 27.677 MiB, 0.01% gc time)
# 133.139157 seconds (660.59 k allocations: 27.382 MiB, 0.01% gc time)
# 143.903085 seconds (665.13 k allocations: 27.585 MiB)
# 132.400545 seconds (660.62 k allocations: 27.375 MiB, 0.01% gc time)
# 130.727784 seconds (659.80 k allocations: 27.314 MiB)
# 128.638822 seconds (660.23 k allocations: 27.323 MiB, 0.01% gc time)
# 136.216206 seconds (646.24 k allocations: 26.751 MiB, 0.01% gc time)
# 139.593683 seconds (651.98 k allocations: 26.924 MiB)
# 136.280645 seconds (655.51 k allocations: 27.141 MiB, 0.01% gc time)
# 134.748911 seconds (655.35 k allocations: 27.161 MiB, 0.01% gc time)
# 135.785703 seconds (655.29 k allocations: 27.175 MiB)
# 129.868228 seconds (660.15 k allocations: 27.313 MiB, 0.01% gc time)
# 129.571440 seconds (659.53 k allocations: 27.342 MiB)
# 134.280668 seconds (661.01 k allocations: 27.516 MiB, 0.01% gc time)
# 128.981235 seconds (660.37 k allocations: 27.357 MiB, 0.01% gc time)
# 125.181746 seconds (654.65 k allocations: 27.111 MiB)
# 122.006110 seconds (655.58 k allocations: 27.210 MiB, 0.01% gc time)
# 121.441794 seconds (654.99 k allocations: 27.145 MiB, 0.01% gc time)
# 125.433422 seconds (659.55 k allocations: 27.290 MiB)
# 124.316411 seconds (660.52 k allocations: 27.387 MiB, 0.01% gc time)
# 126.142597 seconds (659.75 k allocations: 27.325 MiB)
# 127.635238 seconds (664.91 k allocations: 27.540 MiB, 0.01% gc time)
# 130.803356 seconds (665.12 k allocations: 27.558 MiB, 0.01% gc time)
# 129.873929 seconds (659.70 k allocations: 27.296 MiB)
# 131.573535 seconds (655.64 k allocations: 27.184 MiB, 0.01% gc time)
# 129.501840 seconds (655.20 k allocations: 27.150 MiB, 0.01% gc time)
# 129.580383 seconds (654.71 k allocations: 27.024 MiB)
# 134.519988 seconds (655.56 k allocations: 27.095 MiB, 0.01% gc time)
# 130.124512 seconds (654.96 k allocations: 27.151 MiB)
# 127.920966 seconds (655.43 k allocations: 27.176 MiB, 0.01% gc time)
# 128.601967 seconds (657.61 k allocations: 27.236 MiB, 0.01% gc time)
# 128.262556 seconds (657.48 k allocations: 27.346 MiB)
# 137.516754 seconds (661.09 k allocations: 27.517 MiB, 0.01% gc time)
# 136.647192 seconds (660.93 k allocations: 27.528 MiB, 0.01% gc time)
# 134.675507 seconds (660.13 k allocations: 27.425 MiB)
# 131.228420 seconds (662.76 k allocations: 27.549 MiB, 0.01% gc time)
# 130.679756 seconds (664.46 k allocations: 27.523 MiB)
# 126.562109 seconds (660.09 k allocations: 27.312 MiB, 0.01% gc time)
# 122.650620 seconds (659.89 k allocations: 27.286 MiB, 0.01% gc time)
# 121.504696 seconds (659.03 k allocations: 27.212 MiB)
# 121.812033 seconds (659.89 k allocations: 27.286 MiB, 0.01% gc time)
# 123.513801 seconds (659.91 k allocations: 27.322 MiB, 0.01% gc time)
# 126.302596 seconds (654.70 k allocations: 27.049 MiB)
# 126.957226 seconds (655.39 k allocations: 27.085 MiB, 0.01% gc time)
# 128.424712 seconds (654.48 k allocations: 26.997 MiB)
# 127.818044 seconds (657.33 k allocations: 27.192 MiB, 0.01% gc time)
# 129.567955 seconds (655.09 k allocations: 27.031 MiB, 0.01% gc time)
# 127.121402 seconds (654.28 k allocations: 26.962 MiB)
# 133.132920 seconds (655.37 k allocations: 27.075 MiB, 0.01% gc time)
# 132.808494 seconds (650.26 k allocations: 26.930 MiB)
# 131.976543 seconds (655.86 k allocations: 27.228 MiB, 0.01% gc time)
# 137.637811 seconds (660.70 k allocations: 27.380 MiB, 0.01% gc time)
# 132.773519 seconds (659.76 k allocations: 27.311 MiB)
# 133.315271 seconds (660.89 k allocations: 27.499 MiB, 0.01% gc time)
# 134.543817 seconds (660.80 k allocations: 27.411 MiB, 0.01% gc time)
# 134.836412 seconds (660.32 k allocations: 27.386 MiB)
# 138.509542 seconds (665.83 k allocations: 27.654 MiB, 0.01% gc time)
# 130.904539 seconds (664.58 k allocations: 27.536 MiB)
# 134.447351 seconds (660.68 k allocations: 27.370 MiB, 0.01% gc time)
# 132.425007 seconds (660.04 k allocations: 27.262 MiB, 0.01% gc time)
# 132.756425 seconds (654.68 k allocations: 27.003 MiB)
# 122.333124 seconds (654.95 k allocations: 27.032 MiB, 0.01% gc time)
# 122.289935 seconds (654.98 k allocations: 27.040 MiB, 0.01% gc time)
# 124.405046 seconds (654.35 k allocations: 26.986 MiB)
# 127.083491 seconds (655.14 k allocations: 27.032 MiB, 0.01% gc time)
# 127.574493 seconds (654.47 k allocations: 26.995 MiB)
# 127.489978 seconds (650.10 k allocations: 26.774 MiB, 0.01% gc time)
# 128.308878 seconds (649.98 k allocations: 26.747 MiB, 0.01% gc time)
# 128.010278 seconds (649.20 k allocations: 26.680 MiB)
# 135.523373 seconds (655.19 k allocations: 27.593 MiB, 0.01% gc time)
# 134.852992 seconds (655.07 k allocations: 27.050 MiB, 0.01% gc time)
# 135.059264 seconds (655.11 k allocations: 27.159 MiB)
# 132.801382 seconds (660.40 k allocations: 27.339 MiB, 0.01% gc time)
# 131.022410 seconds (659.76 k allocations: 27.311 MiB)
# 130.767782 seconds (660.78 k allocations: 27.478 MiB, 0.01% gc time)
# 130.264165 seconds (660.68 k allocations: 27.409 MiB, 0.01% gc time)
# 127.655707 seconds (660.00 k allocations: 27.432 MiB)
# 123.977717 seconds (660.36 k allocations: 27.371 MiB, 0.01% gc time)
# 125.047504 seconds (660.19 k allocations: 27.436 MiB, 0.01% gc time)
# 122.927334 seconds (659.65 k allocations: 27.380 MiB)
# 122.353595 seconds (660.15 k allocations: 27.323 MiB, 0.01% gc time)
# 120.508023 seconds (653.98 k allocations: 26.936 MiB)
# 122.831174 seconds (654.89 k allocations: 27.019 MiB, 0.01% gc time)
# 120.769834 seconds (649.94 k allocations: 26.834 MiB, 0.01% gc time)
# 122.940001 seconds (649.38 k allocations: 26.788 MiB)
# 124.469096 seconds (649.93 k allocations: 26.750 MiB, 0.01% gc time)
# 126.063468 seconds (649.13 k allocations: 26.674 MiB)
# 127.862722 seconds (649.87 k allocations: 26.721 MiB, 0.01% gc time)
# 127.773510 seconds (645.02 k allocations: 26.554 MiB, 0.01% gc time)
# 128.119069 seconds (644.10 k allocations: 26.395 MiB)
# 135.792513 seconds (650.67 k allocations: 26.914 MiB, 0.01% gc time)
# 137.014603 seconds (655.28 k allocations: 27.075 MiB, 0.01% gc time)
# 135.639456 seconds (654.99 k allocations: 27.066 MiB)
# 132.695091 seconds (660.52 k allocations: 27.345 MiB, 0.01% gc time)
# 133.513713 seconds (659.94 k allocations: 27.331 MiB)
# 129.339935 seconds (660.31 k allocations: 27.344 MiB, 0.01% gc time)
# 128.546323 seconds (655.71 k allocations: 27.218 MiB, 0.01% gc time)
# 126.730849 seconds (659.48 k allocations: 27.274 MiB)
# 123.917761 seconds (660.26 k allocations: 27.349 MiB, 0.01% gc time)
# 123.217972 seconds (654.70 k allocations: 27.128 MiB)
# 121.931050 seconds (656.49 k allocations: 27.195 MiB, 0.01% gc time)
# 121.396964 seconds (654.91 k allocations: 27.033 MiB, 0.01% gc time)
# 121.186480 seconds (654.23 k allocations: 26.979 MiB)
# 120.602648 seconds (650.00 k allocations: 26.838 MiB, 0.01% gc time)
# 119.769878 seconds (649.20 k allocations: 26.645 MiB, 0.01% gc time)
# 120.662393 seconds (644.02 k allocations: 26.414 MiB)
# 121.271580 seconds (644.79 k allocations: 26.466 MiB, 0.01% gc time)
# 123.821318 seconds (643.96 k allocations: 26.385 MiB)
# 125.810676 seconds (644.77 k allocations: 26.450 MiB, 0.01% gc time)
# 126.058814 seconds (644.30 k allocations: 26.360 MiB, 0.01% gc time)
# 126.962156 seconds (638.88 k allocations: 26.155 MiB)
# 138.786695 seconds (647.78 k allocations: 26.800 MiB, 0.01% gc time)
# 136.269442 seconds (649.99 k allocations: 26.798 MiB)
# 133.828142 seconds (650.63 k allocations: 26.904 MiB, 0.01% gc time)
# 132.804044 seconds (655.46 k allocations: 27.085 MiB, 0.01% gc time)
# 134.466099 seconds (654.89 k allocations: 27.052 MiB)
# 131.134110 seconds (655.50 k allocations: 27.101 MiB, 0.01% gc time)
# 130.577640 seconds (655.31 k allocations: 27.169 MiB, 0.01% gc time)
# 127.904652 seconds (654.74 k allocations: 27.114 MiB)
# 126.407333 seconds (655.50 k allocations: 27.171 MiB, 0.01% gc time)
# 124.888511 seconds (654.55 k allocations: 27.027 MiB)
# 122.825279 seconds (654.80 k allocations: 27.006 MiB, 0.01% gc time)
# 121.911747 seconds (654.77 k allocations: 27.002 MiB, 0.01% gc time)
# 121.035310 seconds (649.30 k allocations: 26.720 MiB)
# 121.495995 seconds (649.81 k allocations: 26.737 MiB, 0.01% gc time)
# 121.321452 seconds (644.06 k allocations: 26.416 MiB)
# 120.870345 seconds (639.78 k allocations: 26.209 MiB, 0.02% gc time)
# 121.895175 seconds (639.33 k allocations: 26.187 MiB, 0.01% gc time)
# 120.919300 seconds (638.87 k allocations: 26.115 MiB)
# 123.582296 seconds (634.83 k allocations: 26.000 MiB, 0.01% gc time)
# 125.125804 seconds (633.90 k allocations: 25.837 MiB)
# 125.710396 seconds (634.38 k allocations: 25.844 MiB, 0.01% gc time)
# 135.520168 seconds (640.68 k allocations: 26.388 MiB, 0.01% gc time)
# 136.976405 seconds (645.01 k allocations: 26.589 MiB)
# 134.605834 seconds (655.10 k allocations: 27.006 MiB, 0.01% gc time)
# 133.568680 seconds (649.73 k allocations: 26.760 MiB)
# 133.304196 seconds (655.12 k allocations: 27.019 MiB, 0.01% gc time)
# 133.081252 seconds (655.28 k allocations: 27.050 MiB, 0.01% gc time)
# 131.803852 seconds (651.57 k allocations: 26.895 MiB)
# 129.523467 seconds (654.99 k allocations: 27.011 MiB, 0.01% gc time)
# 129.697389 seconds (654.98 k allocations: 27.050 MiB, 0.01% gc time)
# 125.109630 seconds (654.03 k allocations: 26.933 MiB)
# 124.999234 seconds (654.72 k allocations: 26.962 MiB, 0.01% gc time)
# 121.898537 seconds (649.21 k allocations: 26.710 MiB)
# 121.437227 seconds (644.95 k allocations: 26.496 MiB, 0.02% gc time)
# 121.418680 seconds (644.62 k allocations: 26.448 MiB, 0.01% gc time)
# 119.813676 seconds (639.06 k allocations: 26.223 MiB)
# 120.527901 seconds (634.94 k allocations: 26.035 MiB, 0.01% gc time)
# 118.093843 seconds (633.49 k allocations: 25.860 MiB)
# 110.847795 seconds (629.12 k allocations: 25.657 MiB, 0.01% gc time)
# 101.271815 seconds (625.95 k allocations: 25.466 MiB, 0.01% gc time)
#  97.244218 seconds (623.14 k allocations: 25.351 MiB)
#  97.774572 seconds (623.80 k allocations: 25.370 MiB, 0.01% gc time)
# 136.130815 seconds (639.42 k allocations: 26.232 MiB)
# 136.403903 seconds (645.30 k allocations: 26.513 MiB, 0.01% gc time)
# 135.888244 seconds (640.57 k allocations: 26.525 MiB, 0.01% gc time)
# 134.559851 seconds (646.51 k allocations: 26.601 MiB)
# 133.546483 seconds (645.68 k allocations: 26.643 MiB, 0.01% gc time)
# 135.385990 seconds (649.86 k allocations: 26.838 MiB)
# 132.035366 seconds (650.15 k allocations: 26.769 MiB, 0.01% gc time)
# 131.817539 seconds (650.29 k allocations: 26.795 MiB, 0.01% gc time)
# 129.787358 seconds (649.44 k allocations: 26.721 MiB)
# 128.082157 seconds (650.11 k allocations: 26.754 MiB, 0.01% gc time)
# 125.378466 seconds (648.87 k allocations: 26.631 MiB)
# 124.094467 seconds (644.90 k allocations: 26.486 MiB, 0.01% gc time)
# 122.350843 seconds (644.20 k allocations: 26.368 MiB, 0.01% gc time)
# 121.395640 seconds (638.99 k allocations: 26.138 MiB)
# 120.685575 seconds (634.80 k allocations: 26.009 MiB, 0.01% gc time)
# 106.359041 seconds (628.23 k allocations: 25.598 MiB)
#  97.299568 seconds (628.10 k allocations: 25.535 MiB, 0.01% gc time)
#  94.665959 seconds (622.99 k allocations: 25.267 MiB, 0.02% gc time)
#  93.472910 seconds (617.42 k allocations: 24.973 MiB)
#  93.524845 seconds (614.88 k allocations: 24.881 MiB, 0.02% gc time)
#  81.512342 seconds (607.55 k allocations: 24.567 MiB)
# 137.158231 seconds (637.11 k allocations: 26.094 MiB, 0.01% gc time)
# 135.340798 seconds (639.11 k allocations: 26.106 MiB)
# 135.708738 seconds (645.03 k allocations: 26.460 MiB, 0.01% gc time)
# 134.374280 seconds (644.92 k allocations: 26.515 MiB, 0.01% gc time)
# 134.440182 seconds (644.57 k allocations: 26.459 MiB)
# 133.713178 seconds (640.44 k allocations: 26.343 MiB, 0.01% gc time)
# 133.198548 seconds (649.34 k allocations: 26.685 MiB)
# 132.627158 seconds (650.15 k allocations: 26.755 MiB, 0.01% gc time)
# 130.300853 seconds (645.11 k allocations: 26.504 MiB, 0.01% gc time)
# 127.979720 seconds (644.29 k allocations: 26.428 MiB)
# 126.126728 seconds (639.69 k allocations: 26.235 MiB, 0.01% gc time)
# 124.358406 seconds (638.78 k allocations: 26.157 MiB)
# 121.857899 seconds (634.70 k allocations: 25.925 MiB, 0.01% gc time)
# 122.755082 seconds (634.15 k allocations: 25.829 MiB, 0.01% gc time)
#  97.751332 seconds (627.46 k allocations: 25.433 MiB)
#  96.524574 seconds (619.14 k allocations: 25.260 MiB, 0.02% gc time)
#  94.899690 seconds (617.48 k allocations: 25.042 MiB)
#  83.093571 seconds (609.62 k allocations: 24.691 MiB, 0.02% gc time)
#  80.600491 seconds (607.89 k allocations: 24.573 MiB, 0.02% gc time)
#  79.280067 seconds (604.38 k allocations: 24.338 MiB)
#  76.269055 seconds (602.64 k allocations: 24.265 MiB, 0.02% gc time)

# %%
findmax(capture_vs)
# Out:
# (19.0, CartesianIndex(3, 13))

# %%
Δ1s[3] / Γ
# Out:
# -3.5999999999999996

# %%
Δ1s[13] / Γ
# Out:
# -1.5999999999999999

# %%
capture_vs[end-5,end-5]
# Out:
# 15.0

# %%
using LaTeXStrings

# %%
hm = heatmap(Δ1s ./ Γ, Δ2s ./ Γ, capture_vs')
plot!(
    title="Capture velocity for SrOH MOT",
    xlabel=L"Δ_{J=1/2}\,\,(Γ)",
    ylabel=L"Δ_{J=3/2}\,\,(Γ)",
    size=(520,500),
    xlim=(-4.1,0.1),
    ylim=(-4.1,0.1),
    right_margin=4*Plots.mm
)
scatter!([-1,-3.6], [-1,-1.6], markersize=5, markerfill=nothing, legend=nothing)
annotate!(-1, -1.2, text("SrOH current", 8, :black))
annotate!(-3.6, -1.8, text("Optimum", 8, :black))

# %%
scattered_photons = zeros(Float64, length(Δ1s), length(Δ2s))

for (i,Δ1) ∈ enumerate(Δ1s)
    for (j,Δ2) ∈ enumerate(Δ2s)
        scattered_photons[i,j] = ensemble_sols[(Δ1,Δ2)][9].prob.p.n_scatters
    end
end

# %%
heatmap(Δ1s ./ Γ, Δ2s ./ Γ, scattered_photons')
plot!(
    title="Photons scattered for SrOH MOT",
    xlabel=L"Δ_{J=1/2}\,\,(Γ)",
    ylabel=L"Δ_{J=3/2}\,\,(Γ)",
    size=(520,500),
    xlim=(-4.1,0.1),
    ylim=(-4.1,0.1),
    right_margin=4*Plots.mm
)
scatter!([-1,-3.6], [-1,-1.6], markersize=5, markerfill=nothing, legend=nothing)
annotate!(-1, -1.2, text("SrOH current", 8, :white))
annotate!(-3.6, -1.8, text("Optimum", 8, :white))

# %%
capture_vs[end-3,end-3]
# Out:
# 13.0

# %%
capture_vs[end-5,end-5]
# Out:
# 15.0

# %%
capture_vs[end-18,end-8]
# Out:
# 19.0

# %%
scattered_photons[end-5,end-5]
# Out:
# 31871.0

# %%
scattered_photons[end-18,end-8]
# Out:
# 21871.0
