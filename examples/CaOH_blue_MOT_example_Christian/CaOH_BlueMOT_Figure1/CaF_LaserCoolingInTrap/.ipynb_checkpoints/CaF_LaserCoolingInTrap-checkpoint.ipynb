# %%
using Distributed
procs_to_use = 12
if nprocs() <= procs_to_use
    addprocs(procs_to_use-nprocs())
end
;

# %%
@everywhere using QuantumStates, OpticalBlochEquations, DifferentialEquations, UnitsToValue, StructArrays, StaticArrays, Parameters

@everywhere import Distributions: Normal, Geometric, Exponential
@everywhere using ProgressMeter, Plots
;

# %%
@everywhere include("helper_functions.jl")
include("define_molecular_structure.jl")
include("define_sim_params.jl")
include("define_prob.jl")
include("compute_size_temperature.jl")
;

# %%
using Logging: global_logger
using TerminalLoggers: TerminalLogger
global_logger(TerminalLogger())

prob_periodic.p.add_spontaneous_decay_kick = true
prob_func!(prob_periodic)
@time sol = DifferentialEquations.solve(prob_periodic, progress=true, progress_steps=100000, save_everystep=false, saveat=[])
# @time sol = DifferentialEquations.solve(prob, save_everystep=false, saveat=[])
;
# Out:
# ODE   0%|█                                              |  ETA: N/A
# ODE   4%|███                                            |  ETA: 0:00:17
# ODE   9%|█████                                          |  ETA: 0:00:11
# ODE  14%|███████                                        |  ETA: 0:00:09
# ODE  18%|█████████                                      |  ETA: 0:00:07
# ODE  23%|███████████                                    |  ETA: 0:00:07
# ODE  28%|██████████████                                 |  ETA: 0:00:06
# ODE  33%|████████████████                               |  ETA: 0:00:05
# ODE  38%|██████████████████                             |  ETA: 0:00:05
# ODE  42%|████████████████████                           |  ETA: 0:00:04
# ODE  47%|███████████████████████                        |  ETA: 0:00:04
# ODE  52%|█████████████████████████                      |  ETA: 0:00:03
# ODE  57%|███████████████████████████                    |  ETA: 0:00:03
# ODE  62%|█████████████████████████████                  |  ETA: 0:00:03
# ODE  66%|████████████████████████████████               |  ETA: 0:00:02
# ODE  71%|██████████████████████████████████             |  ETA: 0:00:02
# ODE  76%|████████████████████████████████████           |  ETA: 0:00:02
# ODE  81%|██████████████████████████████████████         |  ETA: 0:00:01
# ODE  86%|█████████████████████████████████████████      |  ETA: 0:00:01
# ODE  91%|███████████████████████████████████████████    |  ETA: 0:00:01
# ODE  95%|█████████████████████████████████████████████  |  ETA: 0:00:00
#   7.134875 seconds (26.60 M allocations: 4.203 GiB, 4.47% gc time, 11.86% compilation time: 100% of which was recompilation)
# ODE 100%|███████████████████████████████████████████████|  ETA: 0:00:00
# ODE 100%|███████████████████████████████████████████████| Time: 0:00:06

# %%
n_trajectories = 10
sols = distributed_solve(n_trajectories, prob_periodic, prob_func!, scan_nothing, [0])
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:26

# %%
i = 120
vxs = [vx(sol.u[i]) for sol ∈ sols[1] if survived(sol,i)]
vys = [vy(sol.u[i]) for sol ∈ sols[1] if survived(sol,i)]
vzs = [vz(sol.u[i]) for sol ∈ sols[1] if survived(sol,i)]
vs = sqrt.(vxs.^2 .+ vys.^2 .+ vzs.^2)

hist_data = fit(Histogram, vxs, -0.3:0.005:0.3)
hist_data.isdensity = true
v = collect(hist_data.edges[1])
dv = v[2]-v[1]
v = v[1:end-1] .+ dv/2
fv = hist_data.weights ./ (sum(hist_data.weights) * dv)

v_fit = curve_fit(maxwell_boltzmann_1D, v, fv, [1, 0.1e-6], autodiff=:forward)
A, temp = v_fit.param

plot(v, fv)
plot!(v, maxwell_boltzmann_1D(v, v_fit.param), color=:red)

# %%
Ts = T_vs_time(sols[1])
display(Ts[end] .* 1e6)
plot(Ts .* 1e6, ylim=(0,100))
# Out:
# 2.201899125795033

# %% [markdown]
# # Include diffusion

# %%
prob_func!(prob_periodic)
@time sol = DifferentialEquations.solve(prob_periodic, progress=true, progress_steps=100000)
;
# Out:
# ODE   0%|█                                              |  ETA: N/A
# ODE   5%|███                                            |  ETA: 0:00:05
# ODE  10%|█████                                          |  ETA: 0:00:04
# ODE  14%|███████                                        |  ETA: 0:00:04
# ODE  19%|█████████                                      |  ETA: 0:00:04
# ODE  23%|███████████                                    |  ETA: 0:00:04
# ODE  28%|██████████████                                 |  ETA: 0:00:04
# ODE  32%|████████████████                               |  ETA: 0:00:03
# ODE  37%|██████████████████                             |  ETA: 0:00:03
# ODE  42%|████████████████████                           |  ETA: 0:00:03
# ODE  47%|███████████████████████                        |  ETA: 0:00:03
# ODE  52%|█████████████████████████                      |  ETA: 0:00:02
# ODE  57%|███████████████████████████                    |  ETA: 0:00:02
# ODE  62%|██████████████████████████████                 |  ETA: 0:00:02
# ODE  67%|████████████████████████████████               |  ETA: 0:00:02
# ODE  72%|██████████████████████████████████             |  ETA: 0:00:01
# ODE  76%|████████████████████████████████████           |  ETA: 0:00:01
# ODE  81%|███████████████████████████████████████        |  ETA: 0:00:01
# ODE  86%|█████████████████████████████████████████      |  ETA: 0:00:01
# ODE  91%|███████████████████████████████████████████    |  ETA: 0:00:00
# ODE  96%|██████████████████████████████████████████████ |  ETA: 0:00:00
#   9.084395 seconds (30.64 M allocations: 1.672 GiB, 9.19% gc time, 46.64% compilation time)
# ODE 100%|███████████████████████████████████████████████| Time: 0:00:04

# %%
prob.p.diffusion_constant = [0.002, 0.002, 0.002]
n_trajectories = 20
sols = distributed_solve(n_trajectories, prob, prob_func!, scan_nothing, [0])
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:02:33

# %%
prob_periodic.p.add_spontaneous_decay_kick = false
prob_periodic.p.diffusion_constant = [0.00, 0.00, 0.00]
n_trajectories = 20
sols = distributed_solve(n_trajectories, prob_periodic, prob_func!, scan_nothing, [0])
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:02:00

# %%
n_trajectories1 = 20
n_trajectories2 = 20
n_trajectories_diffusion = 5000
n_times = 10
diffusion_t_end = 10e-6
diffusion_τ_total = 10e-6
;

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob, prob_func!, prob_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total
)
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:03:04
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:18
# Progress: 100%|█████████████████████████████████████████| Time: 0:03:27
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:14
# Progress: 100%|█████████████████████████████████████████| Time: 0:03:28

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_periodic, prob_func!, prob_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total
)
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:02:22
# Progress: 100%|█████████████████████████████████████████| Time: 4:12:21
# Progress: 100%|█████████████████████████████████████████| Time: 0:11:32

# %%
prob_diffusion.p.diffusion_constant = [0.05, 0.05, 0.05]
n_trajectories_diffusion = 3000
scan_values_with_σ_and_T = zip([0], zip([50e-6], [50e-6], [50e-6], [10e-6], [10e-6], [10e-6]))
(diffusions, diffusion_errors, diffusions_over_time) = distributed_compute_diffusion(
    prob_diffusion, prob_func_diffusion!, n_trajectories_diffusion, diffusion_t_end, diffusion_τ_total, n_times, scan_func_with_initial_conditions!(scan_nothing), scan_values_with_σ_and_T
    )
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:05:31
# ([0.04010115807702021], [0.03571583017469425], [[0.0, 0.027280097983767033, 0.026462753841268893, 0.019116345626002312, 0.02133397570329041, 0.03697507699906544, 0.030761378396009148, 0.03281439958473828, 0.0383674371835855, 0.04010115807702015]])

# %%
prob_diffusion.p.diffusion_constant = [0.05, 0.05, 0.05]
n_trajectories_diffusion = 3000
scan_values_with_σ_and_T = zip([0], zip([50e-6], [50e-6], [50e-6], [10e-6], [10e-6], [10e-6]))
(diffusions, diffusion_errors, diffusions_over_time) = distributed_compute_diffusion(
    prob_diffusion, prob_func_diffusion!, n_trajectories_diffusion, diffusion_t_end, diffusion_τ_total, n_times, scan_func_with_initial_conditions!(scan_nothing), scan_values_with_σ_and_T
    )

# %%
prob_diffusion.p.diffusion_constant = [0.0, 0.0, 0.0]
n_trajectories_diffusion = 20000
scan_values_with_σ_and_T = zip([0], zip([50e-6], [50e-6], [50e-6], [10e-6], [10e-6], [10e-6]))
(diffusions, diffusion_errors, diffusions_over_time) = distributed_compute_diffusion(
    prob_periodic, prob_func!, n_trajectories_diffusion, diffusion_t_end, diffusion_τ_total, n_times, scan_func_with_initial_conditions!(scan_nothing), scan_values_with_σ_and_T
    )
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:28:17
# ([-0.005541793048499199], [0.0054911846884433055], [[0.0, 0.04009091560558909, 0.041780944598801294, 0.02952777500179194, 0.013197546369999404, 0.004105709935428529, -0.00013181802130706952, -0.00258112544653237, -0.005066264994921858, -0.005541793048499229]])

# %%
plot(diffusions_over_time)

# %%
i = 5
z.(sols[1][i].u) |> plot

# %%
Ts = T_vs_time(sols[1])
display(Ts[end] .* 1e6)
plot!(Ts .* 1e6, ylim=(0,300))
# Out:
# 1.1733552051494338

# %%
diffusion_error
# Out:
# UndefVarError: `diffusion_error` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.

# %%
diffusion
# Out:
# 0.32473419375334295

# %%
plot(diffusion_over_time)

# %%
Ts = T_vs_time(sols_with_diffusion)
display(Ts[end] .* 1e6)
plot(Ts .* 1e6, ylim=(0,100))
# Out:
# DomainError with -0.8252072503239345:
# Exponentiation yielding a complex result requires a complex argument.
# Replace x^y with (x+0im)^y, Complex(x)^y, or similar.
#
# Stacktrace:
#   [1] throw_exp_domainerror(x::Float64)
#     @ Base.Math .\math.jl:41
#   [2] ^
#     @ .\math.jl:1157 [inlined]
#   [3] maxwell_boltzmann(v::Vector{Float64}, p::Vector{Float64})
#     @ Main C:\Google Drive\github\OpticalBlochEquations\examples\CaOH_blue_MOT_example_Christian\CaOH_BlueMOT_Figure1\CaF_LaserCoolingInTrap\helper_functions.jl:63
#   [4] #18
#     @ C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\curve_fit.jl:139 [inlined]
#   [5] (::NLSolversBase.var"#ff!#1"{LsqFit.var"#18#20"{typeof(maxwell_boltzmann), Vector{Float64}, Vector{Float64}}})(F::Vector{Float64}, x::Vector{Float64})
#     @ NLSolversBase C:\Users\Christian\.julia\packages\NLSolversBase\kavn7\src\objective_types\inplace_factory.jl:11
#   [6] value(obj::NLSolversBase.OnceDifferentiable{Vector{Float64}, Matrix{Float64}, Vector{Float64}}, F::Vector{Float64}, x::Vector{Float64})
#     @ NLSolversBase C:\Users\Christian\.julia\packages\NLSolversBase\kavn7\src\interface.jl:160
#   [7] levenberg_marquardt(df::NLSolversBase.OnceDifferentiable{Vector{Float64}, Matrix{Float64}, Vector{Float64}}, initial_x::Vector{Float64}; x_tol::Float64, g_tol::Float64, maxIter::Int64, maxTime::Float64, lambda::Float64, tau::Float64, lambda_increase::Float64, lambda_decrease::Float64, min_step_quality::Float64, good_step_quality::Float64, show_trace::Bool, store_trace::Bool, lower::Vector{Float64}, upper::Vector{Float64}, avv!::Nothing)
#     @ LsqFit C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\levenberg_marquardt.jl:245
#   [8] levenberg_marquardt
#     @ C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\levenberg_marquardt.jl:79 [inlined]
#   [9] lmfit(R::NLSolversBase.OnceDifferentiable{Vector{Float64}, Matrix{Float64}, Vector{Float64}}, p0::Vector{Float64}, wt::Vector{Float64}; autodiff::Symbol, kwargs::@Kwargs{})
#     @ LsqFit C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\curve_fit.jl:82
#  [10] lmfit
#     @ C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\curve_fit.jl:75 [inlined]
#  [11] lmfit(f::LsqFit.var"#18#20"{typeof(maxwell_boltzmann), Vector{Float64}, Vector{Float64}}, p0::Vector{Float64}, wt::Vector{Float64}; autodiff::Symbol, kwargs::@Kwargs{})
#     @ LsqFit C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\curve_fit.jl:72
#  [12] lmfit
#     @ C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\curve_fit.jl:54 [inlined]
#  [13] curve_fit(model::typeof(maxwell_boltzmann), xdata::Vector{Float64}, ydata::Vector{Float64}, p0::Vector{Float64}; inplace::Bool, kwargs::@Kwargs{autodiff::Symbol})
#     @ LsqFit C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\curve_fit.jl:140
#  [14] curve_fit
#     @ C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\curve_fit.jl:123 [inlined]
#  [15] T_fit(vs::Vector{Float64})
#     @ Main C:\Google Drive\github\OpticalBlochEquations\examples\CaOH_blue_MOT_example_Christian\CaOH_BlueMOT_Figure1\CaF_LaserCoolingInTrap\helper_functions.jl:108
#  [16] T_ensemble_sol(ensemble_sol::Vector{Any}, i::Int64)
#     @ Main C:\Google Drive\github\OpticalBlochEquations\examples\CaOH_blue_MOT_example_Christian\CaOH_BlueMOT_Figure1\CaF_LaserCoolingInTrap\helper_functions.jl:176
#  [17] T_vs_time(sols::Vector{Any})
#     @ Main C:\Google Drive\github\OpticalBlochEquations\examples\CaOH_blue_MOT_example_Christian\CaOH_BlueMOT_Figure1\CaF_LaserCoolingInTrap\helper_functions.jl:203
#  [18] top-level scope
#     @ In[128]:1

# %%
i = 2
vxs = [vx(sol.u[i]) for sol ∈ sols[1] if survived(sol,i)]
vys = [vy(sol.u[i]) for sol ∈ sols[1] if survived(sol,i)]
vzs = [vz(sol.u[i]) for sol ∈ sols[1] if survived(sol,i)]
vs = sqrt.(vxs.^2 .+ vys.^2 .+ vzs.^2)

hist_data = fit(Histogram, vs, 0:0.005:0.5)
hist_data.isdensity = true
v = collect(hist_data.edges[1])
dv = v[2]-v[1]
v = v[1:end-1] .+ dv/2
fv = hist_data.weights ./ (sum(hist_data.weights) * dv)

v_fit = curve_fit(maxwell_boltzmann, v, fv, [1, 5e-6], autodiff=:forward)
A, temp = v_fit.param

plot(v, fv)
plot!(v, maxwell_boltzmann(v, v_fit.param), color=:red)

# %%
i = 2
vxs = [vx(sol.u[i]) for sol ∈ sols_with_diffusion if survived(sol,i)]
vys = [vy(sol.u[i]) for sol ∈ sols_with_diffusion if survived(sol,i)]
vzs = [vz(sol.u[i]) for sol ∈ sols_with_diffusion if survived(sol,i)]
vs = sqrt.(vxs.^2 .+ vys.^2 .+ vzs.^2)

hist_data = fit(Histogram, vs, 0:0.005:0.5)
hist_data.isdensity = true
v = collect(hist_data.edges[1])
dv = v[2]-v[1]
v = v[1:end-1] .+ dv/2
fv = hist_data.weights ./ (sum(hist_data.weights) * dv)

v_fit = curve_fit(maxwell_boltzmann, v, fv, [1, 5e-6], autodiff=:forward)
A, temp = v_fit.param

plot(v, fv)
plot!(v, maxwell_boltzmann(v, v_fit.param), color=:red)

# %%
i = 1
vxs = [vx(sol.u[i]) for sol ∈ sols_with_diffusion if survived(sol,i)]
vys = [vy(sol.u[i]) for sol ∈ sols_with_diffusion if survived(sol,i)]
vzs = [vz(sol.u[i]) for sol ∈ sols_with_diffusion if survived(sol,i)]
vs = sqrt.(vxs.^2 .+ vys.^2 .+ vzs.^2)

hist_data = fit(Histogram, vxs, -1:0.005:1)
hist_data.isdensity = true
v = collect(hist_data.edges[1])
dv = v[2]-v[1]
v = v[1:end-1] .+ dv/2
fv = hist_data.weights ./ (sum(hist_data.weights) * dv)

v_fit = curve_fit(maxwell_boltzmann_1D, v, fv, [1, 0.1e-6], autodiff=:forward)
A, temp = v_fit.param

plot(v, fv)
plot!(v, maxwell_boltzmann_1D(v, v_fit.param), color=:red)

# %%
prob_1plus2.p.sim_params.s_factor_start = 0.9
prob_1plus2.p.sim_params.s_factor_end = 0.7
;
# Out:
# UndefVarError: `prob_1plus2` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[7]:1

# %%
# n_trajectories1 = 100
# n_trajectories2 = 500
# n_trajectories_diffusion = 100000
n_trajectories1 = 20
n_trajectories2 = 200
n_trajectories_diffusion = 50000
n_times = 10
diffusion_t_end = 10e-6
diffusion_τ_total = 10e-6
;

# %% [markdown]
# ## (a)

# %%
prob_1plus2.p.sim_params.s_factor_start = 1.0
prob_1plus2.p.sim_params.s_factor_end = 1.0
;
# Out:
# UndefVarError: `prob_1plus2` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[9]:1

# %%
# total_sats = (0.3:0.4:2.1) .* total_sat
total_sats = [0.7] .* total_sat
@everywhere function update_total_s!(prob, total_sat)
    prob.p.sim_params.total_sat = total_sat
    return nothing
end
;

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total,
    update_total_s!, total_sats
)
;
# Out:
# UndefVarError: `prob_1plus2` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[11]:1

# %%
plot(diffusion_over_time)
# Out:
# UndefVarError: `diffusion_over_time` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[12]:1

# %%
σxs = σx_fit(sols_with_diffusion)
σys = σy_fit(sols_with_diffusion)
σzs = σz_fit(sols_with_diffusion)
σs = (σxs .* σys .* σzs) .^ (1/3)
plot(total_sats, σs, ylim=(40e-6, 140e-6))
# Out:
# UndefVarError: `sols_with_diffusion` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[13]:1

# %%
Txs = Tx_fit.(sols_with_diffusion)
Tys = Ty_fit.(sols_with_diffusion)
Tzs = Tz_fit.(sols_with_diffusion)
Ts = (Txs .* Tys .* Tzs) .^ (1/3)
plot(total_sats, Ts, ylim=(0, 700e-6))
# Out:
# UndefVarError: `sols_with_diffusion` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[14]:1

# %%
Ts
# Out:
# UndefVarError: `Ts` not defined

# %% [markdown]
# ## (b)

# %%
detunings = [1.68, 3.16, 4.64, 6.12, 7.60, 9.08, 10.56, 12.04, 13.52, 15.00]
@everywhere function update_detuning!(prob, detuning)
    δ1 = +0.00
    δ2 = -1.00
    δ3 = +0.75
    Δ1 = 1e6 * (detuning + δ1) * (2π / Γ)
    Δ2 = 1e6 * (detuning + δ2) * (2π / Γ)
    Δ3 = 1e6 * (detuning + δ3) * (2π / Γ)
    prob.p.ωs[1] = prob.p.ω0s[end] - prob.p.ω0s[1] + Δ1
    prob.p.ωs[2] = prob.p.ω0s[end] - prob.p.ω0s[10] + Δ2
    prob.p.ωs[3] = prob.p.ω0s[end] - prob.p.ω0s[10] + Δ3
    return nothing
end
;

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total,
    update_detuning!, detunings
)
;
# Out:
# UndefVarError: `prob_1plus2` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[17]:1

# %%
plot(diffusion_over_time)
# Out:
# UndefVarError: `diffusion_over_time` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[18]:1

# %%
σxs = σx_fit.(sols_with_diffusion)
σys = σy_fit.(sols_with_diffusion)
σzs = σz_fit.(sols_with_diffusion)
σs = (σxs .* σys .* σzs) .^ (1/3)
plot(detunings, σs, ylim=(40e-6, 140e-6))
# Out:
# UndefVarError: `sols_with_diffusion` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[19]:1

# %%
σs
# Out:
# UndefVarError: `σs` not defined

# %%
Txs = Tx_fit.(sols_with_diffusion)
Tys = Ty_fit.(sols_with_diffusion)
Tzs = Tz_fit.(sols_with_diffusion)
Ts = (Txs .* Tys .* Tzs) .^ (1/3)
plot(detunings, Ts, ylim=(0, 700e-6))
# Out:
# UndefVarError: `sols_with_diffusion` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[21]:1

# %%
Ts
# Out:
# UndefVarError: `Ts` not defined

# %% [markdown]
# ## (c)

# %%
δIIas = collect(range(+0.25, -3.25, 15))
@everywhere function update_δIIa!(prob, δIIa)
    detuning = 7.6
    δ2 = δIIa
    Δ2 = 1e6 * (detuning + δ2) * (2π / Γ)
    prob.p.ωs[2] = prob.p.ω0s[end] - prob.p.ω0s[10] + Δ2
    return nothing
end
;

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total,
    update_δIIa!, δIIas
)
;
# Out:
# UndefVarError: `prob_1plus2` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[24]:1

# %%
σxs = σx_fit.(sols_with_diffusion)
σys = σy_fit.(sols_with_diffusion)
σzs = σz_fit.(sols_with_diffusion)
σs = (σxs .* σys .* σzs) .^ (1/3)
plot(δIIas, (σxs .* σys .* σzs) .^ (1/3), ylim=(40e-6, 140e-6))
# Out:
# UndefVarError: `sols_with_diffusion` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[25]:1

# %%
σs
# Out:
# UndefVarError: `σs` not defined

# %%
Txs = Tx_fit.(sols_with_diffusion)
Tys = Ty_fit.(sols_with_diffusion)
Tzs = Tz_fit.(sols_with_diffusion)
Ts = (Txs .* Tys .* Tzs) .^ (1/3)
plot(δIIas, (Txs .* Tys .* Tzs) .^ (1/3), ylim=(0,700e-6))
# Out:
# UndefVarError: `sols_with_diffusion` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[27]:1

# %%
Ts
# Out:
# UndefVarError: `Ts` not defined

# %% [markdown]
# ## (d)

# %%
collect(δIIbs)
# Out:
# UndefVarError: `δIIbs` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[29]:1

# %%
# δIIbs = range(-0.75, 2.25, 15)
δIIbs = [2.25]
@everywhere function update_δIIb!(prob, δIIb)
    detuning = 7.6
    δ3 = δIIb
    Δ3 = 1e6 * (detuning + δ3) * (2π / Γ)
    prob.p.ωs[3] = prob.p.ω0s[end] - prob.p.ω0s[10] + Δ3
    return nothing
end
;

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total,
    update_δIIb!, δIIbs
)
;
# Out:
# UndefVarError: `prob_1plus2` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[31]:1

# %%
σxs = σx_fit.(sols_with_diffusion)
σys = σy_fit.(sols_with_diffusion)
σzs = σz_fit.(sols_with_diffusion)
σs = (σxs .* σys .* σzs) .^ (1/3)
plot(δIIbs, (σxs .* σys .* σzs) .^ (1/3), ylim=(40e-6,140e-6))
# Out:
# UndefVarError: `sols_with_diffusion` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[32]:1

# %%
σs
# Out:
# UndefVarError: `σs` not defined

# %%
Txs = Tx_fit(sols_with_diffusion)
Tys = Ty_fit(sols_with_diffusion)
Tzs = Tz_fit(sols_with_diffusion)
Ts = (Txs .* Tys .* Tzs) .^ (1/3)
plot(δIIbs, (Txs .* Tys .* Tzs) .^ (1/3), ylim=(0,700e-6))
# Out:
# UndefVarError: `sols_with_diffusion` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[34]:1

# %%
Ts
# Out:
# UndefVarError: `Ts` not defined

# %% [markdown]
# ## (e)

# %%
B_div_C = 0.37/0.28
A_div_BC = [0, 0.37, 1.25, 2.60, 4.5, 7.0, 9.6, 12.6, 15.0, 18.3, 20.9, 22.9]
A_div_BC = A_div_BC ./ (31.4 .- A_div_BC)
A_div_C = A_div_BC .* (1 .+ B_div_C)
C_div_ABC = (A_div_C .+ B_div_C .+ 1).^(-1)
A_div_ABC = A_div_C .* C_div_ABC
B_div_ABC = B_div_C .* C_div_ABC
;

# %%
# all_params = [1300]
# B_div_C = 0.37/0.28
# A_div_C = (1.2 .* all_params / 1100)
# C_div_ABC = (A_div_C .+ B_div_C .+ 1).^(-1)
# A_div_ABC = A_div_C .* C_div_ABC
# B_div_ABC = B_div_C .* C_div_ABC
# ;

# %%
# Calculate the saturation parameters for IIa and IIb for a range of saturation ratios
sat_ratios = zip(B_div_ABC, C_div_ABC, A_div_ABC)

@everywhere function update_sat_ratios!(prob, sat_ratios)
    I_sat_ratio, IIa_sat_ratio, IIb_sat_ratio = sat_ratios
    prob.p.sim_params.s1_ratio = I_sat_ratio
    prob.p.sim_params.s2_ratio = IIa_sat_ratio
    prob.p.sim_params.s3_ratio = IIb_sat_ratio
    return nothing
end

# II_total_sat = sats[2] + sats[3]
# IIab_sats = zip(IIa_sat_ratios .* II_total_sat, IIb_sat_ratios .* II_total_sat)
;

# %%
I_sat_ratio, IIa_sat_ratio, IIb_sat_ratio = first(sat_ratios)
# Out:
# (0.5692307692307692, 0.4307692307692308, 0.0)

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total,
    update_sat_ratios!, sat_ratios
)
;
# Out:
# UndefVarError: `prob_1plus2` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[40]:1

# %%
plot(diffusion_over_time)
# Out:
# UndefVarError: `diffusion_over_time` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[41]:1

# %%
σs
# Out:
# UndefVarError: `σs` not defined

# %%
σxs = σx_fit.(sols_with_diffusion)
σys = σy_fit.(sols_with_diffusion)
σzs = σz_fit.(sols_with_diffusion)
σs = (σxs .* σys .* σzs) .^ (1/3)
plot((σxs .* σys .* σzs) .^ (1/3), ylim=(0,140e-6))
# Out:
# UndefVarError: `sols_with_diffusion` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[43]:1

# %%
Txs = Tx_fit.(sols_with_diffusion)
Tys = Ty_fit.(sols_with_diffusion)
Tzs = Tz_fit.(sols_with_diffusion)
Ts = (Txs .* Tys .* Tzs) .^ (1/3)
plot((Txs .* Tys .* Tzs) .^ (1/3), ylim=(0,700e-6))
# Out:
# UndefVarError: `sols_with_diffusion` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[44]:1

# %%
Ts
# Out:
# UndefVarError: `Ts` not defined

# %%
include("compute_size_temperature.jl")

# %%
prob_1plus2.p.sim_params.s_factor_start = 0.9
prob_1plus2.p.sim_params.s_factor_end = 0.7
;
# Out:
# UndefVarError: `prob_1plus2` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[47]:1

# %%
# n_trajectories1 = 100
# n_trajectories2 = 500
# n_trajectories_diffusion = 100000
n_trajectories1 = 50
n_trajectories2 = 200
n_trajectories_diffusion = 50000
n_times = 10
diffusion_t_end = 20e-6
diffusion_τ_total = 20e-6
;

# %%
B_grads = [25] #25:25:175
@everywhere function update_B_grad!(prob, B_grad)
    prob.p.sim_params.B_grad_end = B_grad
    return nothing
end
;

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total,
    update_B_grad!, B_grads
)
;
# Out:
# UndefVarError: `prob_1plus2` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[50]:1

# %%
plot(diffusion_over_time)
# Out:
# UndefVarError: `diffusion_over_time` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[51]:1

# %%
σs
# Out:
# UndefVarError: `σs` not defined

# %%
σxs = σx_fit(sols_with_diffusion)
σys = σy_fit(sols_with_diffusion)
σzs = σz_fit(sols_with_diffusion)
σs = (σxs .* σys .* σzs) .^ (1/3)
plot(B_grads, σs, ylim=(0e-6,140e-6))
# Out:
# UndefVarError: `sols_with_diffusion` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[53]:1
