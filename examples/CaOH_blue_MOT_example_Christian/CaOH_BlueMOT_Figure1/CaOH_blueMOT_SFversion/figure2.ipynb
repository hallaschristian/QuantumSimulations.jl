# %%
using Distributed
procs_to_use = 10
if nprocs() <= procs_to_use
    addprocs(procs_to_use-nprocs())
end
;

# %%
@everywhere using QuantumStates, OpticalBlochEquations, DifferentialEquations, UnitsToValue, StructArrays, StaticArrays, 
    Parameters

@everywhere import Distributions: Normal, Geometric, Exponential
@everywhere using ProgressMeter, Plots
;

# %%
function flip(ϵ)
    return SVector{3, ComplexF64}(ϵ[3],ϵ[2],ϵ[1])
end
rotate_pol(flip([1,0,0]), +ẑ)
# Out:
# 3-element SVector{3, ComplexF64} with indices SOneTo(3):
#  0.0 + 0.0im
#  0.0 + 0.0im
#  1.0 + 0.0im

# %%
@everywhere include("helper_functions.jl")
include("define_CaOH_molecular_structure.jl")
include("define_sim_params.jl")
include("define_blueMOT_1plus2.jl")
include("define_blueMOT_1plus1.jl")
include("compute_size_temperature.jl")
;

# %%
prob_1plus2.p.diffusion_constant = [0.005, 0.005, 0.005]
prob_1plus2.p.add_spontaneous_decay_kick = false
sols = distributed_solve(3, prob_1plus2, prob_func!, scan_nothing, [0])
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:43

# %%
xs = [x.(sol.u) for sol ∈ sols[1]]
zs = [z.(sol.u) for sol ∈ sols[1]]
;

# %%
plot(zs, legend=nothing)#, ylim=(-0.0005,0.0005))

# %%
T_ensemble_sol(sols[1])
# Out:
# 6.605076824455256e-5

# %%
sols[1][1].prob.p.n_scatters / 20e-3
# Out:
# 159050.0

# %%
n_trajectories_diffusion = 1000
n_times = 100
diffusion_t_end = 20e-6
diffusion_τ_total = 20e-6

prob_1plus2_diffusion.p.diffusion_constant = [0.0, 0.0, 0.0]
scan_values_with_σ_and_T = zip([0], zip([30e-6], [30e-6], [30e-6], [50e-6], [50e-6], [50e-6]))
(diffusions, diffusion_errors, diffusions_over_time) = distributed_compute_diffusion(
    prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories_diffusion, diffusion_t_end, diffusion_τ_total, n_times, scan_func_with_initial_conditions!(scan_nothing), scan_values_with_σ_and_T
    )
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:24

# %%
(diffusions, diffusion_errors) |> display
plot(diffusions_over_time)
# Out:
# ([0.00521962886106353], [0.006349995226331672])

# %% [markdown]
# # Figure 2

# %%
prob_1plus2.p.sim_params.s_factor_start = 1
prob_1plus2.p.sim_params.s_factor_end = 1/3
;

# %%
# n_trajectories1 = 100
# n_trajectories2 = 500
# n_trajectories_diffusion = 100000
n_trajectories1 = 3
n_trajectories2 = 20
n_trajectories_diffusion = 2000
n_times = 100
diffusion_t_end = 10e-6
diffusion_τ_total = 10e-6
;

# %% [markdown]
# ## (a)

# %%
total_sats = (0.3:0.2:2.1) .* total_sat
total_sats = [0.7] .* total_sat
@everywhere function update_total_s!(prob, total_sat)
    prob.p.sim_params.total_sat = total_sat
    return nothing
end
;

# %%
(sols_no_diffusion, sols_with_diffusion1, sols_with_diffusion2, diffusion, diffusion_error, diffusion_over_time1, diffusion_over_time2) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total
)
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:19:17
# Progress: 100%|█████████████████████████████████████████| Time: 1:50:25m25m
# Progress: 100%|█████████████████████████████████████████| Time: 7:07:06m
# Progress: 100%|█████████████████████████████████████████| Time: 1:49:05
# Progress: 100%|█████████████████████████████████████████| Time: 1:29:30

# %%
plot(diffusion_over_time2)

# %%
σxs = σx_fit.(sols_with_diffusion2)
σys = σy_fit.(sols_with_diffusion2)
σzs = σz_fit.(sols_with_diffusion2)
σs = (σxs .* σys .* σzs) .^ (1/3)
σs |> display
plot(total_sats, σs, ylim=(40e-6, 140e-6))
# Out:
# 10-element Vector{Float64}:
#  6.646200275119021e-5
#  6.147365289385484e-5
#  6.0298024757834574e-5
#  6.293443068948016e-5
#  6.679637881317331e-5
#  7.06084086155722e-5
#  7.92014080949135e-5
#  8.325543312223929e-5
#  9.80238724691001e-5
#  9.220829735170344e-5

# %%
Txs = Tx_fit.(sols_with_diffusion2)
Tys = Ty_fit.(sols_with_diffusion2)
Tzs = Tz_fit.(sols_with_diffusion2)
Ts = (Txs .* Tys .* Tzs) .^ (1/3)
Ts |> display
plot(total_sats, Ts, ylim=(0, 700e-6))
# Out:
# 10-element Vector{Float64}:
#  0.00016782846558329028
#  0.0001749524407314544
#  0.0001715774024549222
#  0.0002078507203249674
#  0.0002399701566923514
#  0.0002642411782338924
#  0.00025620625331206266
#  0.0003370966554445925
#  0.0003588477133888338
#  0.00036876218544519844

# %% [markdown]
# ## (b)

# %%
detunings = [1.68, 3.16, 4.64, 6.12, 7.60, 9.08, 10.56, 12.04, 13.52, 15.00]
@everywhere function update_detuning!(prob, detuning)
    δ1 = +0.00
    δ2 = -1.00
    δ3 = +0.75
    Δ1 = 1e6 * (detuning + δ1) * (2π / Γ)
    Δ2 = 1e6 * (detuning + δ2) * (2π / Γ)
    Δ3 = 1e6 * (detuning + δ3) * (2π / Γ)
    prob.p.ωs[1] = prob.p.ω0s[end] - prob.p.ω0s[1] + Δ1
    prob.p.ωs[2] = prob.p.ω0s[end] - prob.p.ω0s[10] + Δ2
    prob.p.ωs[3] = prob.p.ω0s[end] - prob.p.ω0s[10] + Δ3
    return nothing
end
;

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total,
    update_detuning!, detunings
)
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:37:01
# Progress: 100%|█████████████████████████████████████████| Time: 6:14:57m:36
# Progress: 100%|█████████████████████████████████████████| Time: 2:59:32
# Progress: 100%|█████████████████████████████████████████| Time: 6:15:50
# Progress: 100%|█████████████████████████████████████████| Time: 3:14:46

# %%
plot(diffusion_over_time)

# %%
σxs = σx_fit.(sols_with_diffusion)
σys = σy_fit.(sols_with_diffusion)
σzs = σz_fit.(sols_with_diffusion)
σs = (σxs .* σys .* σzs) .^ (1/3)
plot(detunings, σs, ylim=(40e-6, 140e-6))

# %%
σs
# Out:
# 10-element Vector{Float64}:
#  0.00011988005603150527
#  7.882251285790051e-5
#  6.241630506592609e-5
#  6.032761064279177e-5
#  5.968793915001627e-5
#  6.282395655547311e-5
#  6.574450144565045e-5
#  7.658359976030114e-5
#  8.463088740795053e-5
#  0.00010264953783378489

# %%
Txs = Tx_fit.(sols_with_diffusion)
Tys = Ty_fit.(sols_with_diffusion)
Tzs = Tz_fit.(sols_with_diffusion)
Ts = (Txs .* Tys .* Tzs) .^ (1/3)
plot(detunings, Ts, ylim=(0, 700e-6))

# %%
Ts
# Out:
# 10-element Vector{Float64}:
#  0.0009913594776639273
#  0.000395583603111041
#  0.00023833928599509616
#  0.00019128027883086047
#  0.000169955161381314
#  0.0001689448220178511
#  0.0001611663346537858
#  0.00017826679261438816
#  0.00019117885329586503
#  0.00021792957095985674

# %% [markdown]
# ## (c)

# %%
δIIas = collect(range(+0.25, -3.25, 15))
@everywhere function update_δIIa!(prob, δIIa)
    detuning = 7.6
    δ2 = δIIa
    Δ2 = 1e6 * (detuning + δ2) * (2π / Γ)
    prob.p.ωs[2] = prob.p.ω0s[end] - prob.p.ω0s[10] + Δ2
    return nothing
end
;

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total,
    update_δIIa!, δIIas
)
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:54:39
# Progress: 100%|█████████████████████████████████████████| Time: 9:14:24m41
# Progress: 100%|█████████████████████████████████████████| Time: 4:31:22
# Progress: 100%|█████████████████████████████████████████| Time: 8:50:15m
# Progress: 100%|█████████████████████████████████████████| Time: 4:44:21

# %%
σxs = σx_fit.(sols_with_diffusion)
σys = σy_fit.(sols_with_diffusion)
σzs = σz_fit.(sols_with_diffusion)
σs = (σxs .* σys .* σzs) .^ (1/3)
plot(δIIas, (σxs .* σys .* σzs) .^ (1/3), ylim=(40e-6, 140e-6))

# %%
σs
# Out:
# 15-element Vector{Float64}:
#  0.00017321060325200773
#  0.00010738998805188012
#  7.405926817644709e-5
#  6.226173236875769e-5
#  6.016894442149581e-5
#  5.988398192107717e-5
#  6.09948387477598e-5
#  6.2251764538154e-5
#  6.29688223781007e-5
#  6.323097787495827e-5
#  6.568274193722807e-5
#  6.637192327060502e-5
#  6.458631658485089e-5
#  6.41233487927963e-5
#  6.461972019230882e-5

# %%
Txs = Tx_fit.(sols_with_diffusion)
Tys = Ty_fit.(sols_with_diffusion)
Tzs = Tz_fit.(sols_with_diffusion)
Ts = (Txs .* Tys .* Tzs) .^ (1/3)
plot(δIIas, (Txs .* Tys .* Tzs) .^ (1/3), ylim=(0,700e-6))

# %%
Ts
# Out:
# 15-element Vector{Float64}:
#  0.00015985577394579862
#  0.0001523745420871387
#  0.00015026996475827088
#  0.0001420926867340153
#  0.00016070222819407587
#  0.00016659279208645165
#  0.00017879249142172782
#  0.00019332750824337862
#  0.00019486599203985506
#  0.00018424359968492295
#  0.00019330338560488163
#  0.00017511977371729388
#  0.00016230023160052355
#  0.00016111953370618812
#  0.0001529185934626929

# %% [markdown]
# ## (d)

# %%
collect(δIIbs)
# Out:
# 15-element Vector{Float64}:
#  -0.75
#  -0.5357142857142857
#  -0.32142857142857145
#  -0.10714285714285714
#   0.10714285714285714
#   0.32142857142857145
#   0.5357142857142857
#   0.75
#   0.9642857142857143
#   1.1785714285714286
#   1.3928571428571428
#   1.6071428571428572
#   1.8214285714285714
#   2.0357142857142856
#   2.25

# %%
# δIIbs = range(-0.75, 2.25, 15)
δIIbs = [2.25]
@everywhere function update_δIIb!(prob, δIIb)
    detuning = 7.6
    δ3 = δIIb
    Δ3 = 1e6 * (detuning + δ3) * (2π / Γ)
    prob.p.ωs[3] = prob.p.ω0s[end] - prob.p.ω0s[10] + Δ3
    return nothing
end
;

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total,
    update_δIIb!, δIIbs
)
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:46
# Progress: 100%|█████████████████████████████████████████| Time: 0:03:46m03m
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:55
# Progress: 100%|█████████████████████████████████████████| Time: 0:03:35
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:55

# %%
σxs = σx_fit.(sols_with_diffusion)
σys = σy_fit.(sols_with_diffusion)
σzs = σz_fit.(sols_with_diffusion)
σs = (σxs .* σys .* σzs) .^ (1/3)
plot(δIIbs, (σxs .* σys .* σzs) .^ (1/3), ylim=(40e-6,140e-6))
# Out:
# Data contains `Inf` or `NaN` values and a fit cannot be performed
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] check_data_health(xdata::Vector{Float64}, ydata::Vector{Float64})
#     @ LsqFit C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\curve_fit.jl:24
#   [3] curve_fit(model::typeof(gaussian), xdata::Vector{Float64}, ydata::Vector{Float64}, p0::Vector{Float64}; inplace::Bool, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ LsqFit C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\curve_fit.jl:131
#   [4] curve_fit
#     @ C:\Users\Christian\.julia\packages\LsqFit\OglWj\src\curve_fit.jl:123 [inlined]
#   [5] σ_fit(xs::Vector{Float64})
#     @ Main C:\Google Drive\github\OpticalBlochEquations\examples\CaOH_blue_MOT_example_Christian\CaOH_BlueMOT_Figure1\CaOH_blueMOT\helper_functions.jl:98
#   [6] σ_coord_fit
#     @ C:\Google Drive\github\OpticalBlochEquations\examples\CaOH_blue_MOT_example_Christian\CaOH_BlueMOT_Figure1\CaOH_blueMOT\helper_functions.jl:106 [inlined]
#   [7] σx_fit(sols::ODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, Vector{Vector{Vector{Float64}}}, ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, MutableNamedTuple{(:u0, :Γ, :ωs, :ω0s, :eiω0ts, :ϕs, :as, :rs, :kEs, :E_total, :ϵs, :idxs, :denom, :ψ, :dψ, :ψ_q, :sim_params, :d_ge, :d_eg, :F, :d, :d_exp, :d_exp_split, :r, :r_idx, :v_idx, :F_idx, :n_g, :n_excited, :n_states, :m, :add_terms_dψ, :update_params, :decay_dist, :time_to_decay, :last_decay_time, :n_scatters, :diffusion_constant, :add_spontaneous_decay_kick, :sats), Tuple{Base.RefValue{Vector{Float64}}, Base.RefValue{Float64}, Base.RefValue{MVector{3, Float64}}, Base.RefValue{MVector{16, Float64}}, Base.RefValue{StructVector{ComplexF64, NamedTuple{(:re, :im), Tuple{MVector{16, Float64}, MVector{16, Float64}}}, Int64}}, Base.RefValue{MMatrix{3, 6, Float64, 18}}, Base.RefValue{StructArray{ComplexF64, 2, NamedTuple{(:re, :im), Tuple{MMatrix{6, 3, Float64, 18}, MMatrix{6, 3, Float64, 18}}}, Int64}}, Base.RefValue{MMatrix{2, 3, Float64, 6}}, Base.RefValue{StructArray{ComplexF64, 2, NamedTuple{(:re, :im), Tuple{MMatrix{6, 3, Float64, 18}, MMatrix{6, 3, Float64, 18}}}, Int64}}, Base.RefValue{StructVector{ComplexF64, NamedTuple{(:re, :im), Tuple{MVector{3, Float64}, MVector{3, Float64}}}, Int64}}, Base.RefValue{StructArray{ComplexF64, 3, NamedTuple{(:re, :im), Tuple{MArray{Tuple{6, 3, 3}, Float64, 3, 54}, MArray{Tuple{6, 3, 3}, Float64, 3, 54}}}, Int64}}, Base.RefValue{MMatrix{3, 3, Int64, 9}}, Base.RefValue{Float64}, Base.RefValue{StructVector{ComplexF64, NamedTuple{(:re, :im), Tuple{MVector{16, Float64}, MVector{16, Float64}}}, Int64}}, Base.RefValue{StructVector{ComplexF64, NamedTuple{(:re, :im), Tuple{MVector{16, Float64}, MVector{16, Float64}}}, Int64}}, Base.RefValue{StructArray{ComplexF64, 2, NamedTuple{(:re, :im), Tuple{MMatrix{16, 3, Float64, 48}, MMatrix{16, 3, Float64, 48}}}, Int64}}, Base.RefValue{MutableNamedTuple{(:Zeeman_Hx, :Zeeman_Hy, :Zeeman_Hz, :B_ramp_time, :B_grad_start, :B_grad_end, :s_ramp_time, :s_factor_start, :s_factor_end, :photon_budget, :x_dist, :y_dist, :z_dist, :vx_dist, :vy_dist, :vz_dist, :f_z, :total_sat, :s1_ratio, :s2_ratio, :s3_ratio, :Bx, :By, :Bz), Tuple{Base.RefValue{MMatrix{12, 12, Float64, 144}}, Base.RefValue{MMatrix{12, 12, Float64, 144}}, Base.RefValue{MMatrix{12, 12, Float64, 144}}, Base.RefValue{Float64}, Base.RefValue{Float64}, Base.RefValue{Float64}, Base.RefValue{Float64}, Base.RefValue{Float64}, Base.RefValue{Float64}, Base.RefValue{Int64}, Base.RefValue{Normal{Float64}}, Base.RefValue{Normal{Float64}}, Base.RefValue{Normal{Float64}}, Base.RefValue{Normal{Float64}}, Base.RefValue{Normal{Float64}}, Base.RefValue{Normal{Float64}}, Base.RefValue{StructArray{ComplexF64, 2, NamedTuple{(:re, :im), Tuple{Matrix{Float64}, Matrix{Float64}}}, Int64}}, Vararg{Base.RefValue{Float64}, 7}}}}, Base.RefValue{MArray{Tuple{12, 4, 3}, Float64, 3, 144}}, Base.RefValue{MArray{Tuple{4, 12, 3}, Float64, 3, 144}}, Base.RefValue{MVector{3, Float64}}, Base.RefValue{MArray{Tuple{16, 16, 3}, Float64, 3, 768}}, Base.RefValue{StructVector{ComplexF64, NamedTuple{(:re, :im), Tuple{MVector{3, Float64}, MVector{3, Float64}}}, Int64}}, Base.RefValue{StructArray{ComplexF64, 2, NamedTuple{(:re, :im), Tuple{MMatrix{3, 2, Float64, 6}, MMatrix{3, 2, Float64, 6}}}, Int64}}, Base.RefValue{MVector{3, Float64}}, Base.RefValue{Int64}, Base.RefValue{Int64}, Base.RefValue{Int64}, Base.RefValue{Int64}, Base.RefValue{Int64}, Base.RefValue{Int64}, Base.RefValue{Float64}, Base.RefValue{typeof(add_terms_dψ!)}, Base.RefValue{typeof(update_p_1plus2!)}, Base.RefValue{Exponential{Float64}}, Base.RefValue{Float64}, Base.RefValue{Float64}, Base.RefValue{Float64}, Base.RefValue{MVector{3, Float64}}, Base.RefValue{Bool}, Base.RefValue{Vector{Float64}}}}, ODEFunction{true, SciMLBase.AutoSpecialize, FunctionWrappersWrappers.FunctionWrappersWrapper{Tuple{FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{Float64}, Vector{Float64}, MutableN ...
#     @ Main C:\Google Drive\github\OpticalBlochEquations\examples\CaOH_blue_MOT_example_Christian\CaOH_BlueMOT_Figure1\CaOH_blueMOT\helper_functions.jl:108
#   [8] _broadcast_getindex_evalf
#     @ .\broadcast.jl:683 [inlined]
#   [9] _broadcast_getindex
#     @ .\broadcast.jl:656 [inlined]
#  [10] getindex
#     @ .\broadcast.jl:610 [inlined]
#  [11] macro expansion
#     @ .\broadcast.jl:974 [inlined]
#  [12] macro expansion
#     @ .\simdloop.jl:77 [inlined]
#  [13] copyto!(dest::Vector{Float64}, bc::Base.Broadcast.Broadcasted{Nothing, Tuple{Base.OneTo{Int64}}, typeof(σx_fit), Tuple{Vector{Any}}})
#     @ Base.Broadcast .\broadcast.jl:973
#  [14] copyto!
#     @ .\broadcast.jl:926 [inlined]
#  [15] copy
#     @ .\broadcast.jl:898 [inlined]
#  [16] materialize(bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, typeof(σx_fit), Tuple{Vector{Any}}})
#     @ Base.Broadcast .\broadcast.jl:873
#  [17] top-level scope
#     @ In[17]:1

# %%
σs
# Out:
# 7.103561716153844e-5

# %%
Txs = Tx_fit(sols_with_diffusion)
Tys = Ty_fit(sols_with_diffusion)
Tzs = Tz_fit(sols_with_diffusion)
Ts = (Txs .* Tys .* Tzs) .^ (1/3)
plot(δIIbs, (Txs .* Tys .* Tzs) .^ (1/3), ylim=(0,700e-6))
# Out:
# Cannot convert Float64 to series data for plotting
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] _prepare_series_data(x::Float64)
#     @ RecipesPipeline C:\Users\Christian\.julia\packages\RecipesPipeline\BGM3l\src\series.jl:8
#   [3] _series_data_vector(x::Float64, plotattributes::Dict{Symbol, Any})
#     @ RecipesPipeline C:\Users\Christian\.julia\packages\RecipesPipeline\BGM3l\src\series.jl:36
#   [4] macro expansion
#     @ C:\Users\Christian\.julia\packages\RecipesPipeline\BGM3l\src\series.jl:129 [inlined]
#   [5] apply_recipe(plotattributes::AbstractDict{Symbol, Any}, #unused#::Type{RecipesPipeline.SliceIt}, x::Any, y::Any, z::Any)
#     @ RecipesPipeline C:\Users\Christian\.julia\packages\RecipesBase\BRe07\src\RecipesBase.jl:300
#   [6] _process_userrecipes!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline C:\Users\Christian\.julia\packages\RecipesPipeline\BGM3l\src\user_recipe.jl:38
#   [7] recipe_pipeline!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline C:\Users\Christian\.julia\packages\RecipesPipeline\BGM3l\src\RecipesPipeline.jl:72
#   [8] _plot!(plt::Plots.Plot, plotattributes::Any, args::Any)
#     @ Plots C:\Users\Christian\.julia\packages\Plots\kLeqV\src\plot.jl:223
#   [9] plot(::Any, ::Vararg{Any}; kw::Base.Pairs{Symbol, V, Tuple{Vararg{Symbol, N}}, NamedTuple{names, T}} where {V, N, names, T<:Tuple{Vararg{Any, N}}})
#     @ Plots C:\Users\Christian\.julia\packages\Plots\kLeqV\src\plot.jl:102
#  [10] top-level scope
#     @ In[23]:5

# %%
Ts
# Out:
# 0.00023016051584819508

# %% [markdown]
# ## (e)

# %%
B_div_C = 0.37/0.28
A_div_BC = [0, 0.37, 1.25, 2.60, 4.5, 7.0, 9.6, 12.6, 15.0, 18.3, 20.9, 22.9]
A_div_BC = A_div_BC ./ (31.4 .- A_div_BC)
A_div_C = A_div_BC .* (1 .+ B_div_C)
C_div_ABC = (A_div_C .+ B_div_C .+ 1).^(-1)
A_div_ABC = A_div_C .* C_div_ABC
B_div_ABC = B_div_C .* C_div_ABC
;

# %%
# all_params = [1300]
# B_div_C = 0.37/0.28
# A_div_C = (1.2 .* all_params / 1100)
# C_div_ABC = (A_div_C .+ B_div_C .+ 1).^(-1)
# A_div_ABC = A_div_C .* C_div_ABC
# B_div_ABC = B_div_C .* C_div_ABC
# ;

# %%
# Calculate the saturation parameters for IIa and IIb for a range of saturation ratios
sat_ratios = zip(B_div_ABC, C_div_ABC, A_div_ABC)

@everywhere function update_sat_ratios!(prob, sat_ratios)
    I_sat_ratio, IIa_sat_ratio, IIb_sat_ratio = sat_ratios
    prob.p.sim_params.s1_ratio = I_sat_ratio
    prob.p.sim_params.s2_ratio = IIa_sat_ratio
    prob.p.sim_params.s3_ratio = IIb_sat_ratio
    return nothing
end

# II_total_sat = sats[2] + sats[3]
# IIab_sats = zip(IIa_sat_ratios .* II_total_sat, IIb_sat_ratios .* II_total_sat)
;

# %%
I_sat_ratio, IIa_sat_ratio, IIb_sat_ratio = first(sat_ratios)
# Out:
# (0.5692307692307692, 0.4307692307692308, 0.0)

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total,
    update_sat_ratios!, sat_ratios
)
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:05:18
# Progress: 100%|█████████████████████████████████████████| Time: 0:47:29m00
# Progress: 100%|█████████████████████████████████████████| Time: 0:27:15
# Progress: 100%|█████████████████████████████████████████| Time: 0:44:01
# Progress: 100%|█████████████████████████████████████████| Time: 0:26:59

# %%
plot(diffusion_over_time)

# %%
σs
# Out:
# 12-element Vector{Float64}:
#  0.00018492966178179513
#  0.00011929558052647921
#  7.566823799046191e-5
#  6.100298508960273e-5
#  5.551101219434756e-5
#  5.799689635358377e-5
#  5.936167838240508e-5
#  5.979491743178099e-5
#  6.374022239933176e-5
#  6.855162729474784e-5
#  7.839333817605532e-5
#  8.810083184975604e-5

# %%
σxs = σx_fit.(sols_with_diffusion)
σys = σy_fit.(sols_with_diffusion)
σzs = σz_fit.(sols_with_diffusion)
σs = (σxs .* σys .* σzs) .^ (1/3)
plot((σxs .* σys .* σzs) .^ (1/3), ylim=(0,140e-6))

# %%
Txs = Tx_fit.(sols_with_diffusion)
Tys = Ty_fit.(sols_with_diffusion)
Tzs = Tz_fit.(sols_with_diffusion)
Ts = (Txs .* Tys .* Tzs) .^ (1/3)
plot((Txs .* Tys .* Tzs) .^ (1/3), ylim=(0,700e-6))

# %%
Ts
# Out:
# 12-element Vector{Float64}:
#  0.00015329051806780344
#  0.00016270830437951385
#  0.0001490166825754547
#  0.00014871864692124782
#  0.00015703085680570267
#  0.00015241660624928845
#  0.00014686860954845848
#  0.00017140687918841888
#  0.00016579094048937043
#  0.0001879359541159818
#  0.0001975588579249895
#  0.0002427728453816075

# %% [markdown]
# # Figure 3

# %%
n_trajectories1 = 2
n_trajectories2 = 5
n_trajectories_diffusion = 1000
n_times = 10
diffusion_t_end = 3e-6
diffusion_τ_total = 3e-6
;

# %%
(sols_no_diffusion, sols_with_diffusion1, sols_with_diffusion2, diffusion, diffusion_error, diffusion_over_time1, diffusion_over_time2) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total
)
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:08:19
# Progress: 100%|█████████████████████████████████████████| Time: 1:17:52m54m
# Progress: 100%|█████████████████████████████████████████| Time: 1:07:12
# Progress: 100%|█████████████████████████████████████████| Time: 1:15:00
# Progress: 100%|█████████████████████████████████████████| Time: 1:06:45

# %%
plot(diffusion_over_time1)
plot!(diffusion_over_time2)

# %%
σs = []
for i ∈ 40:444
    σ = σ_geom_ensemble_sol(sols_with_diffusion2, i)
    push!(σs, σ)
end
times = range(0,10,length(σs))
plot(times, σs, xlim=(0,15), ylim=(0, 600e-6))

# %%
densities = density_vs_time(sols_with_diffusion2)[40:end]
plot(times, densities, xlim=(0,15))

# %%
for i ∈ 1:15
    t = sols_with_diffusion2[i*1000].t[end] * (1/Γ)
    println( t, " ", sols_with_diffusion2[i*1000].prob.p.n_scatters / t )
end
# Out:
# 0.0017601480926002205 1.227169468910476e6
# 0.0062108948811 1.1716508070590922e6
# 0.011 1.1131818181818184e6
# 0.0028479389617945407 1.1380159629396636e6
# 0.007954388805844438 1.2745165275993508e6
# 0.002113654860795658 1.2329354467166911e6
# 0.00709561772393306 1.2120156883582885e6
# 0.002465932891195544 1.1070860888985628e6
# 0.0032028532718089554 1.1948720953546928e6
# 0.0010331915292871193 1.0724052303879196e6
# 0.005459137620661695 1.2097148778600562e6
# 0.0037657249453901557 1.1031076513129708e6
# 0.011 1.1840909090909092e6
# 0.011 1.3244545454545456e6
# 0.0020893056480971043 1.0716478950981798e6

# %%
io = open("sizes_3freq.txt", "w") do io
    for x in σs
        println(io, x)
    end
end

io = open("times_3freq.txt", "w") do io
    for x in times
        println(io, x)
    end
end

io = open("densities_3freq.txt", "w") do io
    for x in densities
        println(io, x)
    end
end

# %% [markdown]
# ## 1+1 MOT

# %%
n_trajectories1 = 100
n_trajectories2 = 1000
n_trajectories_diffusion = 100000
n_times = 10
diffusion_t_end = 20e-6
diffusion_τ_total = 20e-6
;

# %%
(sols_no_diffusion, sols_with_diffusion1, sols_with_diffusion2, diffusion, diffusion_error, diffusion_over_time1, diffusion_over_time2) = 
    compute_trajectories_with_diffusion(
    prob_1plus1, prob_func!, prob_1plus1_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total
)
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:07:02
# Progress: 100%|█████████████████████████████████████████| Time: 1:22:53
# Progress: 100%|█████████████████████████████████████████| Time: 1:04:03
# Progress: 100%|█████████████████████████████████████████| Time: 1:23:54
# Progress: 100%|█████████████████████████████████████████| Time: 1:03:00

# %%
plot(diffusion_over_time1)
plot!(diffusion_over_time2)

# %%
σs = []
for i ∈ 40:645
    σ = σ_geom_ensemble_sol(sols_with_diffusion2, i)
    push!(σs, σ)
end
times = range(0,15,length(σs))
plot(times, σs, xlim=(0,15), ylim=(0, 600e-6))

# %%
densities = density_vs_time(sols_with_diffusion2)[40:end]
plot(times, densities, xlim=(0,15))

# %%
io = open("sizes_2freq.txt", "w") do io
    for x in σs
        println(io, x)
    end
end

io = open("times_2freq.txt", "w") do io
    for x in times
        println(io, x)
    end
end

io = open("densities_2freq.txt", "w") do io
    for x in densities
        println(io, x)
    end
end

# %% [markdown]
# # Figure 4

# %%
include("compute_size_temperature.jl")

# %%
prob_1plus2.p.sim_params.s_factor_start = 0.9
prob_1plus2.p.sim_params.s_factor_end = 0.7
;

# %%
# n_trajectories1 = 100
# n_trajectories2 = 500
# n_trajectories_diffusion = 100000
n_trajectories1 = 50
n_trajectories2 = 200
n_trajectories_diffusion = 50000
n_times = 10
diffusion_t_end = 20e-6
diffusion_τ_total = 20e-6
;

# %%
B_grads = [25] #25:25:175
@everywhere function update_B_grad!(prob, B_grad)
    prob.p.sim_params.B_grad_end = B_grad
    return nothing
end
;

# %%
(sols_no_diffusion, sols_with_diffusion, diffusion, diffusion_error, diffusion_over_time) = 
    compute_trajectories_with_diffusion(
    prob_1plus2, prob_func!, prob_1plus2_diffusion, prob_func_diffusion!, n_trajectories1, n_trajectories2, n_trajectories_diffusion, n_times, diffusion_t_end, diffusion_τ_total,
    update_B_grad!, B_grads
)
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:02:13
# Progress: 100%|█████████████████████████████████████████| Time: 0:39:12:00
# Progress: 100%|█████████████████████████████████████████| Time: 0:09:21
# Progress: 100%|█████████████████████████████████████████| Time: 0:38:53
# Progress: 100%|█████████████████████████████████████████| Time: 0:09:25

# %%
plot(diffusion_over_time)

# %%
σs
# Out:
# 0.00014537745756582713

# %%
σxs = σx_fit(sols_with_diffusion)
σys = σy_fit(sols_with_diffusion)
σzs = σz_fit(sols_with_diffusion)
σs = (σxs .* σys .* σzs) .^ (1/3)
plot(B_grads, σs, ylim=(0e-6,140e-6))
# Out:
# Cannot convert Float64 to series data for plotting
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] _prepare_series_data(x::Float64)
#     @ RecipesPipeline C:\Users\Christian\.julia\packages\RecipesPipeline\BGM3l\src\series.jl:8
#   [3] _series_data_vector(x::Float64, plotattributes::Dict{Symbol, Any})
#     @ RecipesPipeline C:\Users\Christian\.julia\packages\RecipesPipeline\BGM3l\src\series.jl:36
#   [4] macro expansion
#     @ C:\Users\Christian\.julia\packages\RecipesPipeline\BGM3l\src\series.jl:129 [inlined]
#   [5] apply_recipe(plotattributes::AbstractDict{Symbol, Any}, #unused#::Type{RecipesPipeline.SliceIt}, x::Any, y::Any, z::Any)
#     @ RecipesPipeline C:\Users\Christian\.julia\packages\RecipesBase\BRe07\src\RecipesBase.jl:300
#   [6] _process_userrecipes!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline C:\Users\Christian\.julia\packages\RecipesPipeline\BGM3l\src\user_recipe.jl:38
#   [7] recipe_pipeline!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline C:\Users\Christian\.julia\packages\RecipesPipeline\BGM3l\src\RecipesPipeline.jl:72
#   [8] _plot!(plt::Plots.Plot, plotattributes::Any, args::Any)
#     @ Plots C:\Users\Christian\.julia\packages\Plots\kLeqV\src\plot.jl:223
#   [9] plot(::Any, ::Vararg{Any}; kw::Base.Pairs{Symbol, V, Tuple{Vararg{Symbol, N}}, NamedTuple{names, T}} where {V, N, names, T<:Tuple{Vararg{Any, N}}})
#     @ Plots C:\Users\Christian\.julia\packages\Plots\kLeqV\src\plot.jl:102
#  [10] top-level scope
#     @ In[182]:5
